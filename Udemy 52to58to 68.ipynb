# %%
import pandas as pd
import numpy as np

# %%
# What does Squeeze paraameter change in read_csv() method?   - The conversion of 
#What method parameter is ussed to permanently modify the object the method is called on ?  Ans - inplace
# yOUTUBE - INPLACE use Data School Q&A

# %%
nba = pd.read_csv("nba.csv", squeeze = True)
nba
# Out:
#                   NAME                    TEAM      SALARY    GP   MPG    FG%  \
# 0          Kobe Bryant      Los Angeles Lakers  23500000.0  1280  36.5  0.451
# 1          Joe Johnson           Brooklyn Nets  23180790.0  1048  36.3  0.443
# 2      Carmelo Anthony         New York Knicks  22458401.0   830  36.5  0.455
# 3        Dwight Howard         Houston Rockets  21436271.0   800  35.8  0.579
# 4           Chris Bosh              Miami Heat  20644400.0   840  35.9  0.495
# 5         LeBron James     Cleveland Cavaliers  20644400.0   903  39.3  0.496
# 6           Chris Paul    Los Angeles Clippers  20068563.0   688  36.2  0.473
# 7       Deron Williams           Brooklyn Nets  19754465.0   702  35.1  0.448
# 8             Rudy Gay        Sacramento Kings  19317326.0   648  35.9  0.451
# 9         Kevin Durant   Oklahoma City Thunder  18995624.0   569  38.0  0.481
# 10        Derrick Rose           Chicago Bulls  18862876.0   335  35.9  0.453
# ...

# %%
nba.sort_values("NAME", na_position = "first").head()
# Out:
#               NAME                    TEAM      SALARY   GP   MPG    FG%  \
# 154   Aaron Gordon           Orlando Magic   3992040.0  335  35.9  0.453
# 296     Aaron Gray         Detroit Pistons   1227985.0  569  38.0  0.481
# 251  Adreian Payne  Minnesota Timberwolves   1855320.0  364  35.6  0.524
# 40      Al Horford           Atlanta Hawks  12000000.0  364  35.6  0.524
# 27    Al Jefferson       Charlotte Hornets  13500000.0  759  31.1  0.499
#
#        3P%    FT%  RPG  APG  BLKPG  STLPG   PPG POSITION
# 154  0.306  0.815  3.7  6.5    0.4    0.8  20.5       PF
# 296  0.379  0.881  6.9  3.5    1.0    1.2  27.3        C
# 251  0.256  0.653  9.8  3.9    0.6    1.0  21.5       PF
# 40   0.256  0.653  9.8  3.9    0.6    1.0  21.5        C
# 27   0.131  0.710  9.1  1.6    1.3    0.7  17.0        C

# %%
nba.sort_values("NAME",ascending = False, na_position = "first").head()
# Out:
#               NAME                    TEAM      SALARY   GP   MPG    FG%  \
# 259   Zoran Dragic            Phoenix Suns   1706225.0  770  36.3  0.491
# 121  Zaza Pachulia         Milwaukee Bucks   5200000.0  344  30.9  0.463
# 12   Zach Randolph       Memphis Grizzlies  16500000.0  904  32.0  0.473
# 238    Zach LaVine  Minnesota Timberwolves   2055840.0  757  28.1  0.444
# 317   Xavier Henry      Los Angeles Lakers   1082000.0  561  30.6  0.529
#
#        3P%    FT%   RPG  APG  BLKPG  STLPG   PPG POSITION
# 259  0.288  0.765   4.9  5.9    0.9    1.7  24.1       SG
# 121  0.164  0.733  10.5  2.6    1.1    1.4  18.7        C
# 12   0.263  0.762   9.5  1.8    0.3    0.8  17.1       PF
# 238  0.347  0.853   2.8  4.4    0.1    0.8  11.0       PG
# 317  0.087  0.561   9.2  2.3    1.6    0.7  11.0       SF

# %%
nba.sort_values(["NAME", "SALARY"],ascending = True, na_position = "first").head()
# Out:
#               NAME                    TEAM      SALARY   GP   MPG    FG%  \
# 154   Aaron Gordon           Orlando Magic   3992040.0  335  35.9  0.453
# 296     Aaron Gray         Detroit Pistons   1227985.0  569  38.0  0.481
# 251  Adreian Payne  Minnesota Timberwolves   1855320.0  364  35.6  0.524
# 40      Al Horford           Atlanta Hawks  12000000.0  364  35.6  0.524
# 27    Al Jefferson       Charlotte Hornets  13500000.0  759  31.1  0.499
#
#        3P%    FT%  RPG  APG  BLKPG  STLPG   PPG POSITION
# 154  0.306  0.815  3.7  6.5    0.4    0.8  20.5       PF
# 296  0.379  0.881  6.9  3.5    1.0    1.2  27.3        C
# 251  0.256  0.653  9.8  3.9    0.6    1.0  21.5       PF
# 40   0.256  0.653  9.8  3.9    0.6    1.0  21.5        C
# 27   0.131  0.710  9.1  1.6    1.3    0.7  17.0        C

# %%
nba.sort_values(["NAME", "SALARY"],ascending = [False, True], na_position = "first").head()
# Out:
#               NAME                    TEAM      SALARY   GP   MPG    FG%  \
# 259   Zoran Dragic            Phoenix Suns   1706225.0  770  36.3  0.491
# 121  Zaza Pachulia         Milwaukee Bucks   5200000.0  344  30.9  0.463
# 12   Zach Randolph       Memphis Grizzlies  16500000.0  904  32.0  0.473
# 238    Zach LaVine  Minnesota Timberwolves   2055840.0  757  28.1  0.444
# 317   Xavier Henry      Los Angeles Lakers   1082000.0  561  30.6  0.529
#
#        3P%    FT%   RPG  APG  BLKPG  STLPG   PPG POSITION
# 259  0.288  0.765   4.9  5.9    0.9    1.7  24.1       SG
# 121  0.164  0.733  10.5  2.6    1.1    1.4  18.7        C
# 12   0.263  0.762   9.5  1.8    0.3    0.8  17.1       PF
# 238  0.347  0.853   2.8  4.4    0.1    0.8  11.0       PG
# 317  0.087  0.561   9.2  2.3    1.6    0.7  11.0       SF

# %%
nba["SALARY"].rank(ascending = True)
# Out:
# 0      334.0
# 1      333.0
# 2      332.0
# 3      331.0
# 4      329.5
# 5      329.5
# 6      328.0
# 7      327.0
# 8      326.0
# 9      325.0
# 10     324.0
# 11     323.0
# 12     322.0
# 13     321.0
# 14     320.0
# 15     319.0
# 16     317.5
# 17     317.5
# 18     316.0
# 19     315.0
# 20     313.5
# 21     313.5
# 22     312.0
# 23     310.5
# 24     310.5
# 25     309.0
# 26     308.0
# 27     307.0
# 28     305.5
# 29     305.5
#        ...
# 304     30.0
# 305     30.0
# 306     28.0
# 307     27.0
# 308     26.0
# 309     25.0
# 310     24.0
# 311     23.0
# 312     22.0
# 313     21.0
# 314     20.0
# 315     19.0
# 316     18.0
# 317     17.0
# 318     16.0
# 319     13.5
# 320     13.5
# 321     13.5
# 322     13.5
# 323     11.0
# 324      8.0
# 325      8.0
# 326      8.0
# 327      8.0
# 328      8.0
# 329      3.0
# 330      3.0
# 331      3.0
# 332      3.0
# 333      3.0
# Name: SALARY, Length: 334, dtype: float64

# %%
nba.info()      ##shows count exclude NaN , shows memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 14 columns):
# NAME        334 non-null object
# TEAM        334 non-null object
# SALARY      334 non-null float64
# GP          334 non-null int64
# MPG         334 non-null float64
# FG%         334 non-null float64
# 3P%         334 non-null float64
# FT%         334 non-null float64
# RPG         334 non-null float64
# APG         334 non-null float64
# BLKPG       334 non-null float64
# STLPG       334 non-null float64
# PPG         334 non-null float64
# POSITION    334 non-null object
# dtypes: float64(10), int64(1), object(3)
# memory usage: 36.6+ KB

# %%
newNBA = pd.read_csv("newNBA.csv")
newNBA
# Out:
#                  NAME                    TEAM      SALARY      GP   MPG  \
# 0         Kobe Bryant      Los Angeles Lakers  23500000.0  1280.0  36.5
# 1         Joe Johnson           Brooklyn Nets         NaN  1048.0  36.3
# 2     Carmelo Anthony         New York Knicks  22458401.0     NaN  36.5
# 3       Dwight Howard         Houston Rockets  21436271.0   800.0   NaN
# 4          Chris Bosh              Miami Heat  20644400.0   840.0  35.9
# 5        LeBron James     Cleveland Cavaliers  20644400.0   903.0  39.3
# 6          Chris Paul    Los Angeles Clippers         NaN   688.0  36.2
# 7      Deron Williams           Brooklyn Nets  19754465.0   702.0  35.1
# 8            Rudy Gay        Sacramento Kings  19317326.0   648.0  35.9
# 9        Kevin Durant   Oklahoma City Thunder  18995624.0   569.0  38.0
# 10       Derrick Rose           Chicago Bulls  18862876.0   335.0  35.9
# 11      Blake Griffin    Los Angeles Clippers         NaN   364.0  35.6
# ...

# %%
newNBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 14 columns):
# NAME        99 non-null object
# TEAM        99 non-null object
# SALARY      83 non-null float64
# GP          88 non-null float64
# MPG         87 non-null float64
# FG%         87 non-null float64
# 3P%         88 non-null float64
# FT%         88 non-null float64
# RPG         87 non-null float64
# APG         86 non-null float64
# BLKPG       88 non-null float64
# STLPG       92 non-null float64
# PPG         81 non-null float64
# POSITION    73 non-null object
# dtypes: float64(11), object(3)
# memory usage: 10.9+ KB

# %%
newNBA.dropna()  ##delete or remove rows if atleast one NaN is there
# Out:
#           NAME                TEAM      SALARY      GP   MPG    FG%    3P%  \
# 0  Kobe Bryant  Los Angeles Lakers  23500000.0  1280.0  36.5  0.451  0.334
#
#      FT%  RPG  APG  BLKPG  STLPG   PPG POSITION
# 0  0.837  5.3  4.8    0.5    1.5  25.4       SG

# %%
newNBA.dropna(how = "all")  # if ALL values are NaN drop that NaN label
# Out:
#                  NAME                    TEAM      SALARY      GP   MPG  \
# 0         Kobe Bryant      Los Angeles Lakers  23500000.0  1280.0  36.5
# 1         Joe Johnson           Brooklyn Nets         NaN  1048.0  36.3
# 2     Carmelo Anthony         New York Knicks  22458401.0     NaN  36.5
# 3       Dwight Howard         Houston Rockets  21436271.0   800.0   NaN
# 4          Chris Bosh              Miami Heat  20644400.0   840.0  35.9
# 5        LeBron James     Cleveland Cavaliers  20644400.0   903.0  39.3
# 6          Chris Paul    Los Angeles Clippers         NaN   688.0  36.2
# 7      Deron Williams           Brooklyn Nets  19754465.0   702.0  35.1
# 8            Rudy Gay        Sacramento Kings  19317326.0   648.0  35.9
# 9        Kevin Durant   Oklahoma City Thunder  18995624.0   569.0  38.0
# 10       Derrick Rose           Chicago Bulls  18862876.0   335.0  35.9
# 11      Blake Griffin    Los Angeles Clippers         NaN   364.0  35.6
# ...

# %%
newNBA.dropna(axis = 0)    # shows rows (a.k.a. '0' havong all values)
# Out:
#           NAME                TEAM      SALARY      GP   MPG    FG%    3P%  \
# 0  Kobe Bryant  Los Angeles Lakers  23500000.0  1280.0  36.5  0.451  0.334
#
#      FT%  RPG  APG  BLKPG  STLPG   PPG POSITION
# 0  0.837  5.3  4.8    0.5    1.5  25.4       SG

# %%
newNBA.dropna(axis = 1)        # shows columns (a.k.a. '0' havong all values)
# Out:
#                  NAME                    TEAM
# 0         Kobe Bryant      Los Angeles Lakers
# 1         Joe Johnson           Brooklyn Nets
# 2     Carmelo Anthony         New York Knicks
# 3       Dwight Howard         Houston Rockets
# 4          Chris Bosh              Miami Heat
# 5        LeBron James     Cleveland Cavaliers
# 6          Chris Paul    Los Angeles Clippers
# 7      Deron Williams           Brooklyn Nets
# 8            Rudy Gay        Sacramento Kings
# 9        Kevin Durant   Oklahoma City Thunder
# 10       Derrick Rose           Chicago Bulls
# 11      Blake Griffin    Los Angeles Clippers
# 12      Zach Randolph       Memphis Grizzlies
# 13  LaMarcus Aldridge  Portland Trail Blazers
# 14         Marc Gasol       Memphis Grizzlies
# 15         Kevin Love     Cleveland Cavaliers
# 16  Russell Westbrook   Oklahoma City Thunder
# 17        Brook Lopez           Brooklyn Nets
# 18          David Lee   Golden State Warriors
# ...

# %%
newNBA.dropna(axis = "columns")        # shows columns (a.k.a. '0' havong all values)
# Out:
#                  NAME                    TEAM
# 0         Kobe Bryant      Los Angeles Lakers
# 1         Joe Johnson           Brooklyn Nets
# 2     Carmelo Anthony         New York Knicks
# 3       Dwight Howard         Houston Rockets
# 4          Chris Bosh              Miami Heat
# 5        LeBron James     Cleveland Cavaliers
# 6          Chris Paul    Los Angeles Clippers
# 7      Deron Williams           Brooklyn Nets
# 8            Rudy Gay        Sacramento Kings
# 9        Kevin Durant   Oklahoma City Thunder
# 10       Derrick Rose           Chicago Bulls
# 11      Blake Griffin    Los Angeles Clippers
# 12      Zach Randolph       Memphis Grizzlies
# 13  LaMarcus Aldridge  Portland Trail Blazers
# 14         Marc Gasol       Memphis Grizzlies
# 15         Kevin Love     Cleveland Cavaliers
# 16  Russell Westbrook   Oklahoma City Thunder
# 17        Brook Lopez           Brooklyn Nets
# 18          David Lee   Golden State Warriors
# ...

# %%
newNBA.dropna(axis = "rows") # shows rows (a.k.a. '0' havong all values)
# Out:
#           NAME                TEAM      SALARY      GP   MPG    FG%    3P%  \
# 0  Kobe Bryant  Los Angeles Lakers  23500000.0  1280.0  36.5  0.451  0.334
#
#      FT%  RPG  APG  BLKPG  STLPG   PPG POSITION
# 0  0.837  5.3  4.8    0.5    1.5  25.4       SG

# %%
newNBA.dropna(subset = ["SALARY"]) # shows subset ["SALARY"] non NaN values
# Out:
#                  NAME                    TEAM      SALARY      GP   MPG  \
# 0         Kobe Bryant      Los Angeles Lakers  23500000.0  1280.0  36.5
# 2     Carmelo Anthony         New York Knicks  22458401.0     NaN  36.5
# 3       Dwight Howard         Houston Rockets  21436271.0   800.0   NaN
# 4          Chris Bosh              Miami Heat  20644400.0   840.0  35.9
# 5        LeBron James     Cleveland Cavaliers  20644400.0   903.0  39.3
# 7      Deron Williams           Brooklyn Nets  19754465.0   702.0  35.1
# 8            Rudy Gay        Sacramento Kings  19317326.0   648.0  35.9
# 9        Kevin Durant   Oklahoma City Thunder  18995624.0   569.0  38.0
# 10       Derrick Rose           Chicago Bulls  18862876.0   335.0  35.9
# 12      Zach Randolph       Memphis Grizzlies  16500000.0   904.0  32.0
# 13  LaMarcus Aldridge  Portland Trail Blazers  16006000.0   638.0  35.5
# 14         Marc Gasol       Memphis Grizzlies  15829688.0   505.0  33.7
# ...

# %%
newNBA.dropna(subset = ["SALARY", "POSITION"])     # shows subset ["SALARY", "POSITION"] non NaN values
# Out:
#                  NAME                    TEAM      SALARY      GP   MPG  \
# 0         Kobe Bryant      Los Angeles Lakers  23500000.0  1280.0  36.5
# 2     Carmelo Anthony         New York Knicks  22458401.0     NaN  36.5
# 4          Chris Bosh              Miami Heat  20644400.0   840.0  35.9
# 5        LeBron James     Cleveland Cavaliers  20644400.0   903.0  39.3
# 7      Deron Williams           Brooklyn Nets  19754465.0   702.0  35.1
# 8            Rudy Gay        Sacramento Kings  19317326.0   648.0  35.9
# 9        Kevin Durant   Oklahoma City Thunder  18995624.0   569.0  38.0
# 12      Zach Randolph       Memphis Grizzlies  16500000.0   904.0  32.0
# 13  LaMarcus Aldridge  Portland Trail Blazers  16006000.0   638.0  35.5
# 14         Marc Gasol       Memphis Grizzlies  15829688.0   505.0  33.7
# 15         Kevin Love     Cleveland Cavaliers  15719063.0   431.0   NaN
# 18          David Lee   Golden State Warriors  15012000.0     NaN  31.7
# ...

# %%
#newNBA.fillna(0)   # fills NaN values by 0

# %%
#filinplace_newNBA = newNBA.fillna(0, inplace = True)

# %%
newNBA

# %%
newNBA["POSITION"].fillna("NPlay")
# Out:
# 0        SG
# 1        SF
# 2        SF
# 3     NPlay
# 4         C
# 5        SF
# 6     NPlay
# 7        PG
# 8        SF
# 9        SF
# 10    NPlay
# 11       PF
# 12       PF
# 13       PF
# 14        C
# 15       PF
# 16    NPlay
# 17        C
# 18       PF
# 19       SG
# 20        C
# 21    NPlay
# 22        C
# 23       PG
# 24        C
# 25       SG
# 26    NPlay
# 27        C
# 28       PF
# 29       PG
#       ...
# 69    NPlay
# 70       SG
# 71    NPlay
# 72       PG
# 73       PF
# 74    NPlay
# 75       SF
# 76    NPlay
# 77       SG
# 78       SG
# 79       PG
# 80       PG
# 81       PF
# 82    NPlay
# 83       PG
# 84       PF
# 85       SG
# 86       PF
# 87       SG
# 88       SG
# 89    NPlay
# 90       SG
# 91       SG
# 92       PF
# 93       PG
# 94    NPlay
# 95       PG
# 96       SG
# 97       SG
# 98        C
# Name: POSITION, Length: 99, dtype: object

# %%
df = newNBA["SALARY"].fillna("0")
df.head()
# Out:
# 0       2.35e+07
# 1              0
# 2    2.24584e+07
# 3    2.14363e+07
# 4    2.06444e+07
# Name: SALARY, dtype: object

# %%
df.astype("int").head()     # cast pandas object to specific dtype
# Out:
# 0    23500000
# 1           0
# 2    22458401
# 3    21436271
# 4    20644400
# Name: SALARY, dtype: int32

# %%
newNBA.nunique(dropna = True) # return number of unique elements in the object exclude NaN values
# Out:
# NAME        99
# TEAM        29
# SALARY      76
# GP          39
# MPG         32
# FG%         31
# 3P%         33
# FT%         36
# RPG         34
# APG         31
# BLKPG       16
# STLPG       16
# PPG         32
# POSITION     5
# dtype: int64

# %%
newNBA.nunique(dropna = False)
# Out:
# NAME        99
# TEAM        29
# SALARY      77
# GP          40
# MPG         33
# FG%         32
# 3P%         34
# FT%         37
# RPG         35
# APG         32
# BLKPG       17
# STLPG       17
# PPG         33
# POSITION     6
# dtype: int64

# %%
newNBA["TEAM"].nunique()
# Out:
# 29

# %%
newNBA["POSITION"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
#       ...
# 69     True
# 70    False
# 71     True
# 72    False
# 73    False
# 74     True
# 75    False
# 76     True
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82     True
# 83    False
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# 89     True
# 90    False
# 91    False
# 92    False
# 93    False
# 94     True
# 95    False
# 96    False
# 97    False
# 98    False
# Name: POSITION, Length: 99, dtype: bool

# %%
newNBA[newNBA["POSITION"].isnull()]
# Out:
#                  NAME                    TEAM      SALARY     GP   MPG    FG%  \
# 3       Dwight Howard         Houston Rockets  21436271.0  800.0   NaN  0.579
# 6          Chris Paul    Los Angeles Clippers         NaN  688.0  36.2  0.473
# 10       Derrick Rose           Chicago Bulls  18862876.0  335.0  35.9  0.453
# 16  Russell Westbrook   Oklahoma City Thunder  15719062.0    NaN  33.9  0.432
# 21        Eric Gordon    New Orleans Pelicans         NaN  360.0  34.1  0.438
# 26   Chandler Parsons        Dallas Mavericks  14700000.0  274.0  34.1  0.469
# 31     Derrick Favors               Utah Jazz         NaN  830.0   NaN  0.455
# 35        Serge Ibaka   Oklahoma City Thunder  12350000.0  688.0   NaN  0.473
# 38         David West          Indiana Pacers  12000000.0  569.0  38.0  0.481
# 41      Nicolas Batum  Portland Trail Blazers  11765500.0  904.0  32.0  0.473
# 44       Tyreke Evans    New Orleans Pelicans  11265416.0  431.0  33.0  0.448
# ...

# %%
newNBA["POSITION"].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22     True
# 23     True
# 24     True
# 25     True
# 26    False
# 27     True
# 28     True
# 29     True
#       ...
# 69    False
# 70     True
# 71    False
# 72     True
# 73     True
# 74    False
# 75     True
# 76    False
# 77     True
# 78     True
# 79     True
# 80     True
# 81     True
# 82    False
# 83     True
# 84     True
# 85     True
# 86     True
# 87     True
# 88     True
# 89    False
# 90     True
# 91     True
# 92     True
# 93     True
# 94    False
# 95     True
# 96     True
# 97     True
# 98     True
# Name: POSITION, Length: 99, dtype: bool

# %%
condi = newNBA["POSITION"].isnull()

# %%
newNBA[condi]
# Out:
#                  NAME                    TEAM      SALARY     GP   MPG    FG%  \
# 3       Dwight Howard         Houston Rockets  21436271.0  800.0   NaN  0.579
# 6          Chris Paul    Los Angeles Clippers         NaN  688.0  36.2  0.473
# 10       Derrick Rose           Chicago Bulls  18862876.0  335.0  35.9  0.453
# 16  Russell Westbrook   Oklahoma City Thunder  15719062.0    NaN  33.9  0.432
# 21        Eric Gordon    New Orleans Pelicans         NaN  360.0  34.1  0.438
# 26   Chandler Parsons        Dallas Mavericks  14700000.0  274.0  34.1  0.469
# 31     Derrick Favors               Utah Jazz         NaN  830.0   NaN  0.455
# 35        Serge Ibaka   Oklahoma City Thunder  12350000.0  688.0   NaN  0.473
# 38         David West          Indiana Pacers  12000000.0  569.0  38.0  0.481
# 41      Nicolas Batum  Portland Trail Blazers  11765500.0  904.0  32.0  0.473
# 44       Tyreke Evans    New Orleans Pelicans  11265416.0  431.0  33.0  0.448
# ...

# %%
newNBA["SALARY"].between(6124729, 6924729)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85    False
# 86     True
# 87     True
# 88     True
# 89     True
# 90    False
# 91     True
# 92     True
# 93     True
# 94     True
# 95     True
# 96     True
# 97     True
# 98     True
# Name: SALARY, Length: 99, dtype: bool

# %%
newNBA[newNBA["SALARY"].between(6124729, 6924729)]
# Out:
#                 NAME                    TEAM     SALARY      GP   MPG    FG%  \
# 86      Brandon Bass          Boston Celtics  6900000.0   740.0  29.0    NaN
# 87      Kevin Martin  Minnesota Timberwolves  6792500.0   310.0  24.8  0.449
# 88       J.J. Redick    Los Angeles Clippers  6792500.0   561.0  30.6  0.529
# 89   Wilson Chandler          Denver Nuggets  6757913.0   358.0  25.0  0.514
# 91        J.R. Smith         New York Knicks  6515510.0   535.0  29.9  0.494
# 92       Carl Landry        Sacramento Kings  6500000.0   995.0  32.5  0.494
# 93   Greivis Vasquez         Toronto Raptors  6400000.0   446.0  28.2  0.533
# 94  Derrick Williams        Sacramento Kings  6331404.0   823.0  36.2  0.462
# 95      Jarrett Jack           Brooklyn Nets  6300000.0   259.0  25.4  0.521
# 96       Kyle Korver           Atlanta Hawks  6253521.0   803.0  31.8  0.490
# 97     Landry Fields         Toronto Raptors  6250000.0  1280.0  36.5  0.451
# ...

# %%
newNBA["TEAM"].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 29    False
#       ...
# 69     True
# 70     True
# 71     True
# 72     True
# 73     True
# 74     True
# 75     True
# 76     True
# 77     True
# 78     True
# 79     True
# 80     True
# 81     True
# 82     True
# 83     True
# 84     True
# 85     True
# 86     True
# 87     True
# 88     True
# 89     True
# 90     True
# 91     True
# 92     True
# 93     True
# 94     True
# 95     True
# 96     True
# 97     True
# 98     True
# Name: TEAM, Length: 99, dtype: bool

# %%
newNBA["TEAM"].unique()
# Out:
# array(['Los Angeles Lakers', 'Brooklyn Nets', 'New York Knicks',
#        'Houston Rockets', 'Miami Heat', 'Cleveland Cavaliers',
#        'Los Angeles Clippers', 'Sacramento Kings',
#        'Oklahoma City Thunder', 'Chicago Bulls', 'Memphis Grizzlies',
#        'Portland Trail Blazers', 'Golden State Warriors',
#        'Indiana Pacers', 'New Orleans Pelicans', 'Dallas Mavericks',
#        'Washington Wizards', 'Charlotte Hornets', 'Phoenix Suns',
#        'Utah Jazz', 'San Antonio Spurs', 'Minnesota Timberwolves',
#        'Toronto Raptors', 'Atlanta Hawks', 'Denver Nuggets',
#        'Philadelphia 76ers', 'Milwaukee Bucks', 'Boston Celtics',
#        'Orlando Magic'], dtype=object)

# %%
newNBA["TEAM"].nunique(dropna = False)
# Out:
# 29

# %%
newNBA["TEAM"].duplicated(keep = False)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
#       ...
# 69    True
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
# 78    True
# 79    True
# 80    True
# 81    True
# 82    True
# 83    True
# 84    True
# 85    True
# 86    True
# 87    True
# 88    True
# 89    True
# 90    True
# 91    True
# 92    True
# 93    True
# 94    True
# 95    True
# 96    True
# 97    True
# 98    True
# Name: TEAM, Length: 99, dtype: bool

# %%
mar = -newNBA["TEAM"].duplicated(keep = False)
newNBA[mar]
# Out:
#               NAME           TEAM     SALARY     GP  MPG    FG%    3P%    FT%  \
# 31  Derrick Favors      Utah Jazz        NaN  830.0  NaN  0.455  0.345  0.811
# 65   Channing Frye  Orlando Magic  8579088.0  702.0  NaN  0.448  0.357  0.817
#
#     RPG  APG  BLKPG  STLPG   PPG POSITION
# 31  6.6  3.1    0.5    1.1  25.2      NaN
# 65  3.1  8.5    0.3    1.1   NaN       PF

# %%
newNBA['POSITION'].isin(["C","SG"])
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17     True
# 18    False
# 19     True
# 20     True
# 21    False
# 22     True
# 23    False
# 24     True
# 25     True
# 26    False
# 27     True
# 28    False
# 29    False
#       ...
# 69    False
# 70     True
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77     True
# 78     True
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85     True
# 86    False
# 87     True
# 88     True
# 89    False
# 90     True
# 91     True
# 92    False
# 93    False
# 94    False
# 95    False
# 96     True
# 97     True
# 98     True
# Name: POSITION, Length: 99, dtype: bool

# %%
newNBA["POSITION"] == "SG"
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# 29    False
#       ...
# 69    False
# 70     True
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# 77     True
# 78     True
# 79    False
# 80    False
# 81    False
# 82    False
# 83    False
# 84    False
# 85     True
# 86    False
# 87     True
# 88     True
# 89    False
# 90     True
# 91     True
# 92    False
# 93    False
# 94    False
# 95    False
# 96     True
# 97     True
# 98    False
# Name: POSITION, Length: 99, dtype: bool

# %%
newNBA["POSITION"] != "SG"
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26     True
# 27     True
# 28     True
# 29     True
#       ...
# 69     True
# 70    False
# 71     True
# 72     True
# 73     True
# 74     True
# 75     True
# 76     True
# 77    False
# 78    False
# 79     True
# 80     True
# 81     True
# 82     True
# 83     True
# 84     True
# 85    False
# 86     True
# 87    False
# 88    False
# 89     True
# 90    False
# 91    False
# 92     True
# 93     True
# 94     True
# 95     True
# 96    False
# 97    False
# 98     True
# Name: POSITION, Length: 99, dtype: bool

# %%
mask = newNBA["POSITION"]== "C"
newNBA[mask]        #square bracket
# Out:
#                 NAME                    TEAM      SALARY      GP   MPG    FG%  \
# 4         Chris Bosh              Miami Heat  20644400.0   840.0  35.9    NaN
# 14        Marc Gasol       Memphis Grizzlies  15829688.0   505.0  33.7    NaN
# 17       Brook Lopez           Brooklyn Nets         NaN   400.0  32.4  0.509
# 20       Roy Hibbert          Indiana Pacers  14898938.0   520.0  26.0    NaN
# 22    Tyson Chandler        Dallas Mavericks  14846888.0   910.0  28.8  0.590
# 24  DeMarcus Cousins        Sacramento Kings  14746000.0     NaN  30.9  0.463
# 27      Al Jefferson       Charlotte Hornets  13500000.0   759.0  31.1  0.499
# 30      Andrew Bogut   Golden State Warriors  12972973.0  1048.0  36.3    NaN
# 33       Joakim Noah           Chicago Bulls         NaN   840.0  35.9  0.495
# 37    Nikola Pekovic  Minnesota Timberwolves  12100000.0   648.0  35.9  0.451
# 40        Al Horford           Atlanta Hawks         NaN   364.0  35.6  0.524
# ...

# %%
newNBA
# Out:
#                  NAME                    TEAM      SALARY      GP   MPG  \
# 0         Kobe Bryant      Los Angeles Lakers  23500000.0  1280.0  36.5
# 1         Joe Johnson           Brooklyn Nets         NaN  1048.0  36.3
# 2     Carmelo Anthony         New York Knicks  22458401.0     NaN  36.5
# 3       Dwight Howard         Houston Rockets  21436271.0   800.0   NaN
# 4          Chris Bosh              Miami Heat  20644400.0   840.0  35.9
# 5        LeBron James     Cleveland Cavaliers  20644400.0   903.0  39.3
# 6          Chris Paul    Los Angeles Clippers         NaN   688.0  36.2
# 7      Deron Williams           Brooklyn Nets  19754465.0   702.0  35.1
# 8            Rudy Gay        Sacramento Kings  19317326.0   648.0  35.9
# 9        Kevin Durant   Oklahoma City Thunder  18995624.0   569.0  38.0
# 10       Derrick Rose           Chicago Bulls  18862876.0   335.0  35.9
# 11      Blake Griffin    Los Angeles Clippers         NaN   364.0  35.6
# ...

# %%
mask1 = newNBA["SALARY"] > 14313
mask1
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20     True
# 21    False
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
#       ...
# 69    False
# 70     True
# 71    False
# 72     True
# 73     True
# 74     True
# 75     True
# 76     True
# 77     True
# 78    False
# 79     True
# 80     True
# 81     True
# 82     True
# 83    False
# 84     True
# 85     True
# 86     True
# 87     True
# 88     True
# 89     True
# 90    False
# 91     True
# 92     True
# 93     True
# 94     True
# 95     True
# 96     True
# 97     True
# 98     True
# Name: SALARY, Length: 99, dtype: bool

# %%
mask2 = HR["HourlyRate"] < 65
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-4fc6a5acb281> in <module>
# ----> 1 mask2 = HR["HourlyRate"] < 65
#
# NameError: name 'HR' is not defined

# %%
HR[mask1 & mask2 | mask]
