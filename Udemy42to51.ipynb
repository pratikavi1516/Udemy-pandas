# %%
import pandas as pd
import numpy as np

# %%
google = pd.read_csv("GOOGL.csv", squeeze = True)

# %%
google.head()
# Out:
#          Date        Open        High         Low       Close   Volume  \
# 0  2017-05-03  936.050000  950.200000  935.210000  948.450000  1824800
# 1  2017-05-02  933.270020  942.989990  931.000000  937.090027  1748800
# 2  2017-05-01  924.150024  935.820007  920.799988  932.820007  2323600
# 3  2017-04-28  929.000000  935.900024  923.219971  924.520020  3797800
# 4  2017-04-27  890.000000  893.380005  887.179993  891.440002  2158000
#
#     Adj Close
# 0  948.450000
# 1  937.090027
# 2  932.820007
# 3  924.520020
# 4  891.440002

# %%
def classify_performance (number):
    if number < 300:
        return "Ok"
    elif number >= 300 and number < 650 :
        return "satisfactory"
    else:
        return "Incredible"

# %%
google.Open.apply(classify_performance).tail()
# Out:
# 1996    satisfactory
# 1997    satisfactory
# 1998    satisfactory
# 1999    satisfactory
# 2000              Ok
# Name: Open, dtype: object

# %%
google.Open.mean()
# Out:
# 668.9057707921021

# %%
google.apply(lambda Volume : Volume + 1 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ...

# %%
google.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %%
google.Open*2 + google.High*2
# Out:
# 0       3772.500000
# 1       3752.520020
# 2       3719.940062
# 3       3729.800048
# 4       3566.760010
# 5       3568.760010
# 6       3549.020020
# 7       3496.800048
# 8       3446.119994
# 9       3447.339966
# 10      3435.180054
# 11      3419.859986
# 12      3394.040040
# 13      3369.539916
# 14      3364.359986
# 15      3372.660034
# 16      3376.559936
# 17      3381.760010
# 18      3406.180054
# 19      3430.600098
# 20      3402.000000
# 21      3415.500000
# 22      3392.780030
# 23      3407.959960
# 24      3388.680054
# 25      3370.180052
# 26      3338.940064
# 27      3372.000000
# 28      3366.160034
# 29      3409.659912
#            ...
# 1971    1634.280060
# 1972    1661.640064
# 1973    1701.200012
# 1974    1702.420044
# 1975    1707.600038
# 1976    1683.820010
# 1977    1645.800024
# 1978    1641.939996
# 1979    1631.280072
# 1980    1668.880008
# 1981    1677.340044
# 1982    1668.740012
# 1983    1671.819998
# 1984    1680.800022
# ...

# %%
Pokemon_names = pd.read_csv("pokemon.csv", usecols = ['Name', 'Type 1'], squeeze = True)
Pokemon_names.head()
# Out:
#             Name Type 1
# 0      Bulbasaur  Grass
# 1        Ivysaur  Grass
# 2       Venusaur  Grass
# 3  Mega Venusaur  Grass
# 4     Charmander   Fire

# %%
Pokemon_type = pd.read_csv("pokemon.csv",usecols = ['Name', 'Type 1'], index_col = ['Name'], squeeze = True).to_dict()
Pokemon_type
# Out:
# {'Bulbasaur': 'Grass',
#  'Ivysaur': 'Grass',
#  'Venusaur': 'Grass',
#  'Mega Venusaur': 'Grass',
#  'Charmander': 'Fire',
#  'Charmeleon': 'Fire',
#  'Charizard': 'Fire',
#  'Mega Charizard X': 'Fire',
#  'Mega Charizard Y': 'Fire',
#  'Squirtle': 'Water',
#  'Wartortle': 'Water',
#  'Blastoise': 'Water',
#  'Mega Blastoise': 'Water',
#  'Caterpie': 'Bug',
#  'Metapod': 'Bug',
#  'Butterfree': 'Bug',
#  'Weedle': 'Bug',
#  'Kakuna': 'Bug',
#  'Beedrill': 'Bug',
#  'Mega Beedrill': 'Bug',
#  'Pidgey': 'Normal',
#  'Pidgeotto': 'Normal',
#  'Pidgeot': 'Normal',
#  'Mega Pidgeot': 'Normal',
#  'Rattata': 'Normal',
#  'Raticate': 'Normal',
#  'Spearow': 'Normal',
#  'Fearow': 'Normal',
#  'Ekans': 'Poison',
#  'Arbok': 'Poison',
#  'Pikachu': 'Electric',
#  'Raichu': 'Electric',
#  'Sandshrew': 'Ground',
#  'Sandslash': 'Ground',
#  'Nidoran♀': 'Poison',
#  'Nidorina': 'Poison',
#  'Nidoqueen': 'Poison',
#  'Nidoran♂': 'Poison',
#  'Nidorino': 'Poison',
#  'Nidoking': 'Poison',
# ...

# %%
## Pokemon_names.map(Pokemon_type)
