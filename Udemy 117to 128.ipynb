# %%
import pandas as pd
import numpy as np

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")
Satisfaction = pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
customers.head()
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
foods.head()
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49

# %%
Satisfaction.head()
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3
# 3                    7
# 4                   10

# %%
pd.concat([week1, week2])
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %%
pd.concat([week1, week2], ignore_index = False)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %%
pd.concat([week1, week2], ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# ...

# %%
sales = pd.concat([week1, week2], keys = ["week1", "week2"])
sales
# Out:
#            Customer ID  Food ID
# week1 0            537        9
#       1             97        4
#       2            658        1
#       3            202        2
#       4            155        9
#       5            213        8
#       6            600        1
#       7            503        5
#       8             71        3
#       9            174        3
#       10           961        9
#       11           966        5
#       12           641        4
#       13           288        2
#       14           149        4
#       15           954        2
#       16           147        9
#       17           155        1
#       18           550        6
#       19           101        7
#       20           549        6
#       21            75        6
#       22            78        7
#       23           514        5
#       24           833        7
#       25           329        8
#       26           586       10
#       27           341        1
# ...

# %%
salesm = pd.concat([week1, week2], keys = ["A", "B"])
salesm
# Out:
#        Customer ID  Food ID
# A 0            537        9
#   1             97        4
#   2            658        1
#   3            202        2
#   4            155        9
#   5            213        8
#   6            600        1
#   7            503        5
#   8             71        3
#   9            174        3
#   10           961        9
#   11           966        5
#   12           641        4
#   13           288        2
#   14           149        4
#   15           954        2
#   16           147        9
#   17           155        1
#   18           550        6
#   19           101        7
#   20           549        6
#   21            75        6
#   22            78        7
#   23           514        5
#   24           833        7
#   25           329        8
#   26           586       10
#   27           341        1
#   28           519       10
#   29           680        9
# ...            ...      ...
# B 220          495        2
# ...

# %%
salesm.ix["A"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# ...

# %%
salesm.ix[("B", 240)]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Customer ID    734
# Food ID          1
# Name: (B, 240), dtype: int64

# %%
salesm.ix[("B", 240), "Customer ID"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 734

# %%
salesm.ix[("B", 240), "Food ID"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 1

# %%
week2.append(week1)
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# 5            310        5
# 6            761        2
# 7            443        5
# 8            729        9
# 9            741        8
# 10           847        6
# 11           156       10
# 12           550        7
# 13           620       10
# 14           272        4
# 15           511        2
# 16             8        6
# 17           534        7
# 18           909        6
# 19           732        9
# 20           372        4
# 21           713        1
# 22           496        3
# 23           381        9
# 24            13        2
# 25           101        4
# 26           325        7
# 27           674        2
# 28           564        8
# 29           578        5
# ..           ...      ...
# 220          147        8
# 221          745        4
# 222          184        3
# ...

# %%
week2.append(week1, ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# 5            310        5
# 6            761        2
# 7            443        5
# 8            729        9
# 9            741        8
# 10           847        6
# 11           156       10
# 12           550        7
# 13           620       10
# 14           272        4
# 15           511        2
# 16             8        6
# 17           534        7
# 18           909        6
# 19           732        9
# 20           372        4
# 21           713        1
# 22           496        3
# 23           381        9
# 24            13        2
# 25           101        4
# 26           325        7
# 27           674        2
# 28           564        8
# 29           578        5
# ..           ...      ...
# 470          147        8
# 471          745        4
# 472          184        3
# ...

# %%
week1.merge(week2, how = "inner", on = "Customer ID")
# Out:
#     Customer ID  Food ID_x  Food ID_y
# 0           537          9          5
# 1           155          9          3
# 2           155          1          3
# 3           503          5          8
# 4           503          5          9
# 5           550          6          7
# 6           101          7          4
# 7            75          6          4
# 8            77          1          7
# 9            77          9          7
# 10           77          2          7
# 11           77          9          7
# 12          628          4          7
# 13          798          9          5
# 14          798          1          5
# 15          462          3          8
# 16          304          3          3
# 17          304          2          3
# 18          189          4          5
# 19          799          8          7
# 20           30          2          4
# 21          249          9          6
# 22          677         10          3
# 23          741          3          8
# ...

# %%
week1.merge(week2, how = "inner", on = "Customer ID", suffixes = ["_week1", "_week2"]).head()
# Out:
#    Customer ID  Food ID_week1  Food ID_week2
# 0          537              9              5
# 1          155              9              3
# 2          155              1              3
# 3          503              5              8
# 4          503              5              9

# %%
week1[week1["Customer ID"]== 155 ]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"]== 155 ]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
week1.merge(week2, how = "inner", on = ["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
merged = week1.merge(week2, how = "outer", on = "Customer ID", suffixes = ["_week1", "_week2"], indicator = True)
merged.head()
# Out:
#    Customer ID  Food ID_week1  Food ID_week2     _merge
# 0          537            9.0            5.0       both
# 1           97            4.0            NaN  left_only
# 2          658            1.0            NaN  left_only
# 3          202            2.0            NaN  left_only
# 4          155            9.0            3.0       both

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
merged["_merge"].isin(["left_only", "right_only"]).head()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: _merge, dtype: bool

# %%
pd.merge(week1, customers, how="left", left_on = "Customer ID", right_on = "ID").head()
# Out:
#    Customer ID  Food ID   ID First Name Last Name  Gender    Company  \
# 0          537        9  537     Cheryl   Carroll  Female   Zoombeat
# 1           97        4   97     Amanda   Watkins  Female        Ozu
# 2          658        1  658    Patrick      Webb    Male  Browsebug
# 3          202        2  202      Louis  Campbell    Male  Rhynoodle
# 4          155        9  155    Carolyn      Diaz  Female   Gigazoom
#
#                       Occupation
# 0               Registered Nurse
# 1            Account Coordinator
# 2  Community Outreach Specialist
# 3     Account Representative III
# 4     Database Administrator III

# %%
week1.merge(foods, how= "left", on = "Food ID", sort = True).head()
# Out:
#    Customer ID  Food ID Food Item  Price
# 0          658        1     Sushi   3.99
# 1          600        1     Sushi   3.99
# 2          155        1     Sushi   3.99
# 3          341        1     Sushi   3.99
# 4           20        1     Sushi   3.99

# %%
week2.merge(customers, how = "left", left_on = "Customer ID", right_on = "ID", sort = True).drop("ID", axis = "columns")
# Out:
#      Customer ID  Food ID   First Name  Last Name  Gender        Company  \
# 0              8        6      Frances      Adams  Female       Dabshots
# 1             13        2         Ruth    Alvarez  Female    Twitterlist
# 2             21        4       Albert      Burns    Male      Rhynoodle
# 3             24        8        Donna     Thomas  Female        Jaxbean
# 4             27        4      Jessica    Bennett  Female  Twitternation
# 5             30        4       Pamela      Hicks  Female          Ntags
# 6             35        8       Nicole    Chapman  Female        Pixonyx
# 7             39       10       Teresa   Harrison  Female            Oba
# 8             45        8         Earl   Marshall    Male          Agivu
# 9             46        6         Adam       Cole    Male          Trupe
# 10            54        8       Amanda      Berry  Female        Jaxspan
# 11            55        9        Ralph       Ford    Male     Browsezoom
# ...

# %%
salen = week1.merge(customers, how = "left", left_on = "Customer ID", right_index = True)

# %%
salen.merge (foods, how = "left", left_on = "Food ID", right_index = True)
# Out:
#      Customer ID  Food ID_x     ID  First Name   Last Name  Gender  \
# 0            537          9  538.0        Sara  Washington  Female
# 1             97          4   98.0        Jean       Mills  Female
# 2            658          1  659.0      Howard      Hudson    Male
# 3            202          2  203.0       Annie        Lane  Female
# 4            155          9  156.0   Stephanie       Kelly  Female
# 5            213          8  214.0       Robin      Hanson  Female
# 6            600          1  601.0      Johnny      Murphy    Male
# 7            503          5  504.0       Keith       Jones    Male
# 8             71          3   72.0    Lawrence     Schmidt    Male
# 9            174          3  175.0       Ralph       White    Male
# 10           961          9  962.0       James      Murphy    Male
# 11           966          5  967.0       Ralph       Davis    Male
# 12           641          4  642.0       Scott        Ward    Male
# ...

# %%
  week1.merge(Satisfaction, how = "left", left_index = True, right_index = True).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %%
week1.join(Satisfaction).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10
