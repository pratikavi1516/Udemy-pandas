# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("TEMPERATURE.xls")
df
# Out:
#          DAY  temperature  windspeed  event
# 0 2019-01-11           32          6   RAIN
# 1 2019-01-12           24          7  SUNNY
# 2 2019-01-13           28          2   SNOW
# 3 2019-01-14           24          7   SNOW
# 4 2019-01-15           32          4   RAIN
# 5 2019-01-16           32          2  SUNNY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# DAY            6 non-null datetime64[ns]
# temperature    6 non-null int64
# windspeed      6 non-null int64
# event          6 non-null object
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
pd.to_datetime(df["temperature"])
# Out:
# 0   1970-01-01 00:00:00.000000032
# 1   1970-01-01 00:00:00.000000024
# 2   1970-01-01 00:00:00.000000028
# 3   1970-01-01 00:00:00.000000024
# 4   1970-01-01 00:00:00.000000032
# 5   1970-01-01 00:00:00.000000032
# Name: temperature, dtype: datetime64[ns]

# %%
dfn = pd.read_excel("TEMPERATURE.xls" , parse_dates = ["windspeed", "temperature"])
dfn
# Out:
#          DAY  temperature  windspeed  event
# 0 2019-01-11           32          6   RAIN
# 1 2019-01-12           24          7  SUNNY
# 2 2019-01-13           28          2   SNOW
# 3 2019-01-14           24          7   SNOW
# 4 2019-01-15           32          4   RAIN
# 5 2019-01-16           32          2  SUNNY

# %%
dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# DAY            6 non-null datetime64[ns]
# temperature    6 non-null int64
# windspeed      6 non-null int64
# event          6 non-null object
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 272.0+ bytes

# %% [markdown]
# # isin()
# isnull()
# notnull()
# between()
# duplicated()
# drop_duplicates()
# unique()
# nuniques()

# %%
HR = pd.read_csv("HR-Employee-Attrition.csv")
HR.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
HR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
HR["Gender"]== "Male"
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4        True
# 5        True
# 6       False
# 7        True
# 8        True
# 9        True
# 10       True
# 11      False
# 12       True
# 13       True
# 14       True
# 15      False
# 16       True
# 17       True
# 18      False
# 19       True
# 20      False
# 21       True
# 22      False
# 23       True
# 24       True
# 25      False
# 26      False
# 27       True
# 28      False
# 29      False
#         ...
# 1440    False
# 1441     True
# 1442     True
# 1443     True
# 1444     True
# 1445    False
# 1446    False
# 1447     True
# 1448     True
# 1449     True
# 1450    False
# 1451    False
# 1452     True
# 1453    False
# 1454    False
# 1455     True
# 1456     True
# 1457    False
# 1458    False
# 1459     True
# 1460    False
# 1461     True
# 1462    False
# 1463     True
# 1464    False
# 1465     True
# 1466     True
# 1467     True
# 1468     True
# 1469     True
# ...

# %%
HR["Gender"]!= "Male"
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
# 5       False
# 6        True
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15       True
# 16      False
# 17      False
# 18       True
# 19      False
# 20       True
# 21      False
# 22       True
# 23      False
# 24      False
# 25       True
# 26       True
# 27      False
# 28       True
# 29       True
#         ...
# 1440     True
# 1441    False
# 1442    False
# 1443    False
# 1444    False
# 1445     True
# 1446     True
# 1447    False
# 1448    False
# 1449    False
# 1450     True
# 1451     True
# 1452    False
# 1453     True
# 1454     True
# 1455    False
# 1456    False
# 1457     True
# 1458     True
# 1459    False
# 1460     True
# 1461    False
# 1462     True
# 1463    False
# 1464     True
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# ...

# %%
mask = HR["Department"]== "Sales"
HR[mask]        #square bracket
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 0      41       Yes      Travel_Rarely       1102      Sales
# 18     53        No      Travel_Rarely       1219      Sales
# 21     36       Yes      Travel_Rarely       1218      Sales
# 27     42        No      Travel_Rarely        691      Sales
# 29     46        No      Travel_Rarely        705      Sales
# 33     39       Yes      Travel_Rarely        895      Sales
# 36     50       Yes      Travel_Rarely        869      Sales
# 37     35        No      Travel_Rarely        890      Sales
# 39     33        No  Travel_Frequently       1141      Sales
# 43     27        No  Travel_Frequently        994      Sales
# 46     34        No         Non-Travel       1065      Sales
# 48     46        No  Travel_Frequently       1211      Sales
# 52     44        No      Travel_Rarely       1488      Sales
# 54     26        No      Travel_Rarely       1443      Sales
# ...

# %%
HR["Attrition"].replace({"Yes": "True",
                        "No" : "False"} )
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14       True
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21       True
# 22      False
# 23      False
# 24       True
# 25      False
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 1440    False
# 1441    False
# 1442     True
# 1443    False
# 1444     True
# 1445    False
# 1446    False
# 1447    False
# 1448    False
# 1449    False
# 1450    False
# 1451    False
# 1452     True
# 1453    False
# 1454    False
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# 1460    False
# 1461     True
# 1462    False
# 1463    False
# 1464    False
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# ...

# %%
mask1 = HR["MonthlyRate"] > 14313

# %%
c

# %%
HR[mask1 & mask2 | mask]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 12     31        No      Travel_Rarely        670  Research & Development
# 18     53        No      Travel_Rarely       1219                   Sales
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 22     34        No      Travel_Rarely        419  Research & Development
# 27     42        No      Travel_Rarely        691                   Sales
# 29     46        No      Travel_Rarely        705                   Sales
# 31     44        No      Travel_Rarely       1459  Research & Development
# 33     39       Yes      Travel_Rarely        895                   Sales
# ...
