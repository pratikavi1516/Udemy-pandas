# %%
import pandas as pd
import numpy as np

# %%
bond = pd.read_csv("James_Bond_007_Movie_Data.csv")
bond.set_index('Film', inplace = True)
bond.head()
# Out:
#                        Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Dr. No                 1962          NaN  Sean Connery                      1
# From Russia With Love  1963          1.0  Sean Connery                      2
# Goldfinger             1964          1.0  Sean Connery                      3
# Thunderball            1965          1.0  Sean Connery                      4
# You Only Live Twice    1967          2.0  Sean Connery                      5
#
#                        Villians Dispatched  Others' Dispatched  \
# Film
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
# Goldfinger                               9                  68
# Thunderball                             20                  90
# You Only Live Twice                     21                 175
#
#                        Total Dispatched  Adjusted box office  \
# Film
# ...

# %%
bond.rename(columns = {
    "Year" : "Release date",
    "Bond actor" : "Actor",
    "Actual box office" : "Profit"
}, inplace = True)

# %%
bond.head()
# Out:
#                        Release date  Years lapse         Actor  \
# Film
# Dr. No                         1962          NaN  Sean Connery
# From Russia With Love          1963          1.0  Sean Connery
# Goldfinger                     1964          1.0  Sean Connery
# Thunderball                    1965          1.0  Sean Connery
# You Only Live Twice            1967          2.0  Sean Connery
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# Dr. No                                     1                    4
# From Russia With Love                      2                   11
# Goldfinger                                 3                    9
# Thunderball                                4                   20
# You Only Live Twice                        5                   21
#
#                        Others' Dispatched  Total Dispatched  \
# Film
# Dr. No                                  8                12
# ...

# %%
bond.columns
# Out:
# Index(['Release date', 'Years lapse', 'Actor', 'Bond actor appearance',
#        'Villians Dispatched', 'Others' Dispatched', 'Total Dispatched',
#        'Adjusted box office', 'Profit', 'Adjusted budget', 'Actual budget',
#        'Director', 'Rotten Tomatoes critic score',
#        'Rotten Tomatoes audience score', 'Golden Globe nominations',
#        'Golden Globe wins', 'Academy Award nominations', 'Academy Award wins',
#        'Number of Bond drinks', 'Bond girls', 'Bond car make',
#        'Runtime minutes', 'Month released', 'Rating', 'Bond, James Bond said'],
#       dtype='object')

# %%
# bond.columns = ["Films", "date", "Years lapse", "Actor", "actor appearance",
       "Villians ", "Others Dispatched", "Total Dispatched",
       "Adjusted box office", "Profit", "Adjusted budget", "Actual budget",
       "Director", "critic score",
       "audience score", " nominations",
       "Golden Globe wins", "Academy Award nominations", "Academy Award wins",
       "Number of Bond drinks", "Bond girls", "Bond car make",
       "Runtime minutes", "Month released", "Rating", "Bond, James Bond said"]
# Out:
#   File "<ipython-input-6-23beb2016f29>", line 2
#     "Villians ", "Others Dispatched", "Total Dispatched",
#     ^
# IndentationError: unexpected indent

# %%
#delete rows and columns from dataframe

# %%
bond.head(1)
# Out:
#         Release date  Years lapse         Actor  Bond actor appearance  \
# Film
# Dr. No          1962          NaN  Sean Connery                      1
#
#         Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Dr. No                    4                   8                12
#
#         Adjusted box office  Profit  Adjusted budget  ...  Golden Globe wins  \
# Film                                                  ...
# Dr. No                448.8    59.5              7.0  ...                  1
#
#        Academy Award nominations Academy Award wins Number of Bond drinks  \
# Film
# Dr. No                         0                  0                  11.5
#
#         Bond girls  Bond car make  Runtime minutes  Month released  Rating  \
# Film
# Dr. No           3        Sunbeam              110         October      PG
#
#         Bond, James Bond said
# Film
# Dr. No                      1
#
# [1 rows x 25 columns]

# %%
bond.drop(columns= 'Bond actor appearance').head(1)
# Out:
#         Release date  Years lapse         Actor  Villians Dispatched  \
# Film
# Dr. No          1962          NaN  Sean Connery                    4
#
#         Others' Dispatched  Total Dispatched  Adjusted box office  Profit  \
# Film
# Dr. No                   8                12                448.8    59.5
#
#         Adjusted budget  Actual budget  ... Golden Globe wins  \
# Film                                    ...
# Dr. No              7.0            1.1  ...                 1
#
#        Academy Award nominations Academy Award wins  Number of Bond drinks  \
# Film
# Dr. No                         0                  0                   11.5
#
#         Bond girls  Bond car make  Runtime minutes  Month released  Rating  \
# Film
# Dr. No           3        Sunbeam              110         October      PG
#
#        Bond, James Bond said
# Film
# Dr. No                     1
#
# [1 rows x 24 columns]

# %%
bond.columns
# Out:
# Index(['Release date', 'Years lapse', 'Actor', 'Bond actor appearance',
#        'Villians Dispatched', 'Others' Dispatched', 'Total Dispatched',
#        'Adjusted box office', 'Profit', 'Adjusted budget', 'Actual budget',
#        'Director', 'Rotten Tomatoes critic score',
#        'Rotten Tomatoes audience score', 'Golden Globe nominations',
#        'Golden Globe wins', 'Academy Award nominations', 'Academy Award wins',
#        'Number of Bond drinks', 'Bond girls', 'Bond car make',
#        'Runtime minutes', 'Month released', 'Rating', 'Bond, James Bond said'],
#       dtype='object')

# %%
bondi = bond.drop(columns =["Bond actor appearance",
                    "Villians Dispatched",
                    "Others' Dispatched",
                    "Total Dispatched",
                    "Adjusted box office",
                    "Rotten Tomatoes critic score",
       "Rotten Tomatoes audience score",
                    "Golden Globe nominations",
                    "Academy Award nominations", "Academy Award wins",
       "Number of Bond drinks", "Bond girls",
                    
       ])

# %%
bondi
# Out:
#                                  Release date  Years lapse           Actor  \
# Film
# Dr. No                                   1962          NaN    Sean Connery
# From Russia With Love                    1963          1.0    Sean Connery
# Goldfinger                               1964          1.0    Sean Connery
# Thunderball                              1965          1.0    Sean Connery
# You Only Live Twice                      1967          2.0    Sean Connery
# On Her Majesty's Secret Service          1969          2.0  George Lazenby
# Diamonds Are Forever                     1971          2.0    Sean Connery
# Live and Let Die                         1973          2.0     Roger Moore
# The Man with the Golden Gun              1974          1.0     Roger Moore
# The Spy Who Loved Me                     1977          3.0     Roger Moore
# Moonraker                                1979          2.0     Roger Moore
# ...

# %%
bondi.drop("Thunderball" ).head()
# Out:
#                                  Release date  Years lapse           Actor  \
# Film
# Dr. No                                   1962          NaN    Sean Connery
# From Russia With Love                    1963          1.0    Sean Connery
# Goldfinger                               1964          1.0    Sean Connery
# You Only Live Twice                      1967          2.0    Sean Connery
# On Her Majesty's Secret Service          1969          2.0  George Lazenby
#
#                                  Profit  Adjusted budget  Actual budget  \
# Film
# Dr. No                             59.5              7.0            1.1
# From Russia With Love              78.9             12.6            2.0
# Goldfinger                        124.9             18.6            3.0
# You Only Live Twice               101.0             59.9           10.3
# On Her Majesty's Secret Service    64.6             37.3            7.0
#
# ...

# %%
bondi.drop("Thunderball", axis = 0 )
# Out:
#                                  Release date  Years lapse           Actor  \
# Film
# Dr. No                                   1962          NaN    Sean Connery
# From Russia With Love                    1963          1.0    Sean Connery
# Goldfinger                               1964          1.0    Sean Connery
# You Only Live Twice                      1967          2.0    Sean Connery
# On Her Majesty's Secret Service          1969          2.0  George Lazenby
# Diamonds Are Forever                     1971          2.0    Sean Connery
# Live and Let Die                         1973          2.0     Roger Moore
# The Man with the Golden Gun              1974          1.0     Roger Moore
# The Spy Who Loved Me                     1977          3.0     Roger Moore
# Moonraker                                1979          2.0     Roger Moore
# For Your Eyes Only                       1981          2.0     Roger Moore
# ...

# %%
actor = bond.pop("Bond car make")   #removes "Bond car make" permanently

# %%
bond.head(1)
# Out:
#         Release date  Years lapse         Actor  Bond actor appearance  \
# Film
# Dr. No          1962          NaN  Sean Connery                      1
#
#         Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Dr. No                    4                   8                12
#
#         Adjusted box office  Profit  Adjusted budget  ...  \
# Film                                                  ...
# Dr. No                448.8    59.5              7.0  ...
#
#         Golden Globe nominations Golden Globe wins Academy Award nominations  \
# Film
# Dr. No                         1                 1                         0
#
#        Academy Award wins  Number of Bond drinks  Bond girls  Runtime minutes  \
# Film
# Dr. No                  0                   11.5           3              110
#
#         Month released  Rating  Bond, James Bond said
# Film
# Dr. No         October      PG                      1
#
# [1 rows x 24 columns]

# %%
actor
# Out:
# Film
# Dr. No                                   Sunbeam
# From Russia With Love                    Bentley
# Goldfinger                          Aston Martin
# Thunderball                              Lincoln
# You Only Live Twice                       Toyota
# On Her Majesty's Secret Service     Aston Martin
# Diamonds Are Forever                        Ford
# Live and Let Die                       Chevrolet
# The Man with the Golden Gun                  AMC
# The Spy Who Loved Me                       Lotus
# Moonraker                                Bentley
# For Your Eyes Only                         Lotus
# Octopussy                          Mercedes-Benz
# A View to a Kill                         Renault
# The Living Daylights                Aston Martin
# Licence to Kill                          Lincoln
# GoldenEye                                    BMW
# Tomorrow Never Dies                          BMW
# The World is Not Enough                      BMW
# ...

# %%
del bond ["Month released"]
bond.head()
# Out:
#                        Release date  Years lapse         Actor  \
# Film
# Dr. No                         1962          NaN  Sean Connery
# From Russia With Love          1963          1.0  Sean Connery
# Goldfinger                     1964          1.0  Sean Connery
# Thunderball                    1965          1.0  Sean Connery
# You Only Live Twice            1967          2.0  Sean Connery
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# Dr. No                                     1                    4
# From Russia With Love                      2                   11
# Goldfinger                                 3                    9
# Thunderball                                4                   20
# You Only Live Twice                        5                   21
#
#                        Others' Dispatched  Total Dispatched  \
# Film
# Dr. No                                  8                12
# ...

# %%
bond.sample(n= 5)    #create random sample
# Out:
#                        Release date  Years lapse           Actor  \
# Film
# Octopussy                      1983          2.0     Roger Moore
# Tomorrow Never Dies            1997          2.0  Pierce Brosnan
# Casino Royale                  2006          4.0    Daniel Craig
# Skyfall                        2012          4.0    Daniel Craig
# From Russia With Love          1963          1.0    Sean Connery
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# Octopussy                                  6                   15
# Tomorrow Never Dies                        2                   30
# Casino Royale                              1                   11
# Skyfall                                    3                   26
# From Russia With Love                      2                   11
#
#                        Others' Dispatched  Total Dispatched  \
# Film
# Octopussy                              43                58
# ...

# %%
bond.sample(n= 5, axis= 1)    #create random sample
# Out:
#                                  Bond girls  Bond actor appearance  \
# Film
# Dr. No                                    3                      1
# From Russia With Love                     3                      2
# Goldfinger                                5                      3
# Thunderball                               5                      4
# You Only Live Twice                       4                      5
# On Her Majesty's Secret Service           3                      1
# Diamonds Are Forever                      5                      6
# Live and Let Die                          3                      1
# The Man with the Golden Gun               4                      2
# The Spy Who Loved Me                      3                      3
# Moonraker                                 4                      4
# For Your Eyes Only                        3                      5
# Octopussy                                 3                      6
# ...

# %%
bond.sample(frac= 0.25)
# Out:
#                      Release date  Years lapse           Actor  \
# Film
# Tomorrow Never Dies          1997          2.0  Pierce Brosnan
# Octopussy                    1983          2.0     Roger Moore
# Thunderball                  1965          1.0    Sean Connery
# Die Another Day              2002          3.0  Pierce Brosnan
# For Your Eyes Only           1981          2.0     Roger Moore
# Quantum of Solace            2008          2.0    Daniel Craig
#
#                      Bond actor appearance  Villians Dispatched  \
# Film
# Tomorrow Never Dies                      2                   30
# Octopussy                                6                   15
# Thunderball                              4                   20
# Die Another Day                          4                   31
# For Your Eyes Only                       5                   18
# Quantum of Solace                        2                   16
#
# ...

# %%
bond.sort_values("Adjusted box office", ascending= False).head(3)
# Out:
#              Release date  Years lapse         Actor  Bond actor appearance  \
# Film
# Skyfall              2012          4.0  Daniel Craig                      3
# Thunderball          1965          1.0  Sean Connery                      4
# Goldfinger           1964          1.0  Sean Connery                      3
#
#              Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Skyfall                       26                  23                49
# Thunderball                   20                  90               110
# Goldfinger                     9                  68                77
#
#              Adjusted box office  Profit  Adjusted budget  ...  \
# Film                                                       ...
# Skyfall                    879.8  1108.6            158.1  ...
# Thunderball                848.1   141.2             41.9  ...
# Goldfinger                 820.4   124.9             18.6  ...
#
# ...

# %%
bond.nlargest(3,"Adjusted box office")
# Out:
#              Release date  Years lapse         Actor  Bond actor appearance  \
# Film
# Skyfall              2012          4.0  Daniel Craig                      3
# Thunderball          1965          1.0  Sean Connery                      4
# Goldfinger           1964          1.0  Sean Connery                      3
#
#              Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Skyfall                       26                  23                49
# Thunderball                   20                  90               110
# Goldfinger                     9                  68                77
#
#              Adjusted box office  Profit  Adjusted budget  ...  \
# Film                                                       ...
# Skyfall                    879.8  1108.6            158.1  ...
# Thunderball                848.1   141.2             41.9  ...
# Goldfinger                 820.4   124.9             18.6  ...
#
# ...

# %%
bond.nsmallest(3,"Adjusted box office")
# Out:
#                                  Release date  Years lapse           Actor  \
# Film
# Licence to Kill                          1989          2.0  Timothy Dalton
# A View to a Kill                         1985          2.0     Roger Moore
# On Her Majesty's Secret Service          1969          2.0  George Lazenby
#
#                                  Bond actor appearance  Villians Dispatched  \
# Film
# Licence to Kill                                      2                   10
# A View to a Kill                                     7                    5
# On Her Majesty's Secret Service                      1                    5
#
#                                  Others' Dispatched  Total Dispatched  \
# Film
# Licence to Kill                                  13                23
# A View to a Kill                                 57                62
# On Her Majesty's Secret Service                  37                42
#
# ...

# %%
bond["Adjusted box office"].nsmallest(3)
# Out:
# Film
# Licence to Kill                    250.9
# A View to a Kill                   275.2
# On Her Majesty's Secret Service    291.5
# Name: Adjusted box office, dtype: float64

# %%
bond["Adjusted box office"].nlargest(3)
# Out:
# Film
# Skyfall        879.8
# Thunderball    848.1
# Goldfinger     820.4
# Name: Adjusted box office, dtype: float64

# %%
#filtering with where column

# %%
ask = bond["Actor"] == "Sean Connery"
bond[ask]
# Out:
#                        Release date  Years lapse         Actor  \
# Film
# Dr. No                         1962          NaN  Sean Connery
# From Russia With Love          1963          1.0  Sean Connery
# Goldfinger                     1964          1.0  Sean Connery
# Thunderball                    1965          1.0  Sean Connery
# You Only Live Twice            1967          2.0  Sean Connery
# Diamonds Are Forever           1971          2.0  Sean Connery
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# Dr. No                                     1                    4
# From Russia With Love                      2                   11
# Goldfinger                                 3                    9
# Thunderball                                4                   20
# You Only Live Twice                        5                   21
# Diamonds Are Forever                       6                    7
#
# ...

# %%
bond.where(ask)
# Out:
#                                  Release date  Years lapse         Actor  \
# Film
# Dr. No                                 1962.0          NaN  Sean Connery
# From Russia With Love                  1963.0          1.0  Sean Connery
# Goldfinger                             1964.0          1.0  Sean Connery
# Thunderball                            1965.0          1.0  Sean Connery
# You Only Live Twice                    1967.0          2.0  Sean Connery
# On Her Majesty's Secret Service           NaN          NaN           NaN
# Diamonds Are Forever                   1971.0          2.0  Sean Connery
# Live and Let Die                          NaN          NaN           NaN
# The Man with the Golden Gun               NaN          NaN           NaN
# The Spy Who Loved Me                      NaN          NaN           NaN
# Moonraker                                 NaN          NaN           NaN
# For Your Eyes Only                        NaN          NaN           NaN
# ...

# %%
bond.where(bond["Profit"] > 100)
# Out:
#                                  Release date  Years lapse           Actor  \
# Film
# Dr. No                                    NaN          NaN             NaN
# From Russia With Love                     NaN          NaN             NaN
# Goldfinger                             1964.0          1.0    Sean Connery
# Thunderball                            1965.0          1.0    Sean Connery
# You Only Live Twice                    1967.0          2.0    Sean Connery
# On Her Majesty's Secret Service           NaN          NaN             NaN
# Diamonds Are Forever                   1971.0          2.0    Sean Connery
# Live and Let Die                       1973.0          2.0     Roger Moore
# The Man with the Golden Gun               NaN          NaN             NaN
# The Spy Who Loved Me                   1977.0          3.0     Roger Moore
# Moonraker                              1979.0          2.0     Roger Moore
# ...

# %%
ask2 = bond["Profit"]> 100

# %%
bond.where(ask & ask2)
# Out:
#                                  Release date  Years lapse         Actor  \
# Film
# Dr. No                                    NaN          NaN           NaN
# From Russia With Love                     NaN          NaN           NaN
# Goldfinger                             1964.0          1.0  Sean Connery
# Thunderball                            1965.0          1.0  Sean Connery
# You Only Live Twice                    1967.0          2.0  Sean Connery
# On Her Majesty's Secret Service           NaN          NaN           NaN
# Diamonds Are Forever                   1971.0          2.0  Sean Connery
# Live and Let Die                          NaN          NaN           NaN
# The Man with the Golden Gun               NaN          NaN           NaN
# The Spy Who Loved Me                      NaN          NaN           NaN
# Moonraker                                 NaN          NaN           NaN
# For Your Eyes Only                        NaN          NaN           NaN
# ...

# %%
bond.where(ask | ask2)
# Out:
#                                  Release date  Years lapse           Actor  \
# Film
# Dr. No                                 1962.0          NaN    Sean Connery
# From Russia With Love                  1963.0          1.0    Sean Connery
# Goldfinger                             1964.0          1.0    Sean Connery
# Thunderball                            1965.0          1.0    Sean Connery
# You Only Live Twice                    1967.0          2.0    Sean Connery
# On Her Majesty's Secret Service           NaN          NaN             NaN
# Diamonds Are Forever                   1971.0          2.0    Sean Connery
# Live and Let Die                       1973.0          2.0     Roger Moore
# The Man with the Golden Gun               NaN          NaN             NaN
# The Spy Who Loved Me                   1977.0          3.0     Roger Moore
# Moonraker                              1979.0          2.0     Roger Moore
# ...

# %%
bond.columns = [column_name.replace("" , ".") for column_name in bond.columns]
bond.columns
# Out:
# Index(['.R.e.l.e.a.s.e. .d.a.t.e.', '.Y.e.a.r.s. .l.a.p.s.e.', '.A.c.t.o.r.',
#        '.B.o.n.d. .a.c.t.o.r. .a.p.p.e.a.r.a.n.c.e.',
#        '.V.i.l.l.i.a.n.s. .D.i.s.p.a.t.c.h.e.d.',
#        '.O.t.h.e.r.s.'. .D.i.s.p.a.t.c.h.e.d.',
#        '.T.o.t.a.l. .D.i.s.p.a.t.c.h.e.d.',
#        '.A.d.j.u.s.t.e.d. .b.o.x. .o.f.f.i.c.e.', '.P.r.o.f.i.t.',
#        '.A.d.j.u.s.t.e.d. .b.u.d.g.e.t.', '.A.c.t.u.a.l. .b.u.d.g.e.t.',
#        '.D.i.r.e.c.t.o.r.',
#        '.R.o.t.t.e.n. .T.o.m.a.t.o.e.s. .c.r.i.t.i.c. .s.c.o.r.e.',
#        '.R.o.t.t.e.n. .T.o.m.a.t.o.e.s. .a.u.d.i.e.n.c.e. .s.c.o.r.e.',
#        '.G.o.l.d.e.n. .G.l.o.b.e. .n.o.m.i.n.a.t.i.o.n.s.',
#        '.G.o.l.d.e.n. .G.l.o.b.e. .w.i.n.s.',
#        '.A.c.a.d.e.m.y. .A.w.a.r.d. .n.o.m.i.n.a.t.i.o.n.s.',
#        '.A.c.a.d.e.m.y. .A.w.a.r.d. .w.i.n.s.',
#        '.N.u.m.b.e.r. .o.f. .B.o.n.d. .d.r.i.n.k.s.', '.B.o.n.d. .g.i.r.l.s.',
#        '.B.o.n.d. .c.a.r. .m.a.k.e.', '.R.u.n.t.i.m.e. .m.i.n.u.t.e.s.',
# ...
