# %%
import pandas as pd
import numpy as np

# %%
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html #

# %%
Pokemonz = pd.read_csv("pokemon.csv")
Pokemonz.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
dir(Pokemonz)
# Out:
# ['Attack',
#  'Defense',
#  'Generation',
#  'HP',
#  'Legendary',
#  'Name',
#  'Speed',
#  'T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
# ...

# %%
sorted(Pokemonz)
# Out:
# ['#',
#  'Attack',
#  'Defense',
#  'Generation',
#  'HP',
#  'Legendary',
#  'Name',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Type 1',
#  'Type 2']

# %%
list(Pokemonz)
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %%
max(Pokemonz)
# Out:
# 'Type 2'

# %%
min(Pokemonz)
# Out:
# '#'

# %%
Pokemonz.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
Pokemonz.ndim
# Out:
# 2

# %%
Pokemonz.shape
# Out:
# (800, 12)

# %%
Pokemonz.size
# Out:
# 9600

# %%
Pokemonz.values
# Out:
# array([[1, 'Bulbasaur', 'Grass', ..., 45, 1, False],
#        [2, 'Ivysaur', 'Grass', ..., 60, 1, False],
#        [3, 'Venusaur', 'Grass', ..., 80, 1, False],
#        ...,
#        [798, 'Hoopa Confined', 'Psychic', ..., 70, 6, True],
#        [799, 'Hoopa Unbound', 'Psychic', ..., 80, 6, True],
#        [800, 'Volcanion', 'Fire', ..., 70, 6, True]], dtype=object)

# %%
Pokemonz.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
Pokemon = pd.read_csv("pokemon.csv", usecols = ['Name', 'Type 1'], squeeze = True)

# %%
Pokemon.head()
# Out:
#             Name Type 1
# 0      Bulbasaur  Grass
# 1        Ivysaur  Grass
# 2       Venusaur  Grass
# 3  Mega Venusaur  Grass
# 4     Charmander   Fire

# %%
Pokemon.Name.is_unique
# Out:
# True

# %%
Pokemon.max
# Out:
# <bound method DataFrame.max of                        Name    Type 1
# 0                 Bulbasaur     Grass
# 1                   Ivysaur     Grass
# 2                  Venusaur     Grass
# 3             Mega Venusaur     Grass
# 4                Charmander      Fire
# 5                Charmeleon      Fire
# 6                 Charizard      Fire
# 7          Mega Charizard X      Fire
# 8          Mega Charizard Y      Fire
# 9                  Squirtle     Water
# 10                Wartortle     Water
# 11                Blastoise     Water
# 12           Mega Blastoise     Water
# 13                 Caterpie       Bug
# 14                  Metapod       Bug
# 15               Butterfree       Bug
# 16                   Weedle       Bug
# 17                   Kakuna       Bug
# 18                 Beedrill       Bug
# 19            Mega Beedrill       Bug
# 20                   Pidgey    Normal
# 21                Pidgeotto    Normal
# 22                  Pidgeot    Normal
# ...

# %%
Pokemon.Name.sort_values()
# Out:
# 510                 Abomasnow
# 68                       Abra
# 392                     Absol
# 678                  Accelgor
# 750     Aegislash Blade Forme
# 751    Aegislash Shield Forme
# 153                Aerodactyl
# 332                    Aggron
# 205                     Aipom
# 70                   Alakazam
# 655                 Alomomola
# 365                   Altaria
# 768                    Amaura
# 471                   Ambipom
# 652                 Amoonguss
# 195                  Ampharos
# 379                   Anorith
# 29                      Arbok
# 64                   Arcanine
# 552                    Arceus
# 627                    Archen
# 628                  Archeops
# 182                   Ariados
# 380                   Armaldo
# 753                Aromatisse
# 330                      Aron
# 156                  Articuno
# 590                    Audino
# 769                   Aurorus
# 789                   Avalugg
#                 ...
# ...

# %%
Pokemon.Name.sort_values(ascending = False).head()    #sorts in descending order
# Out:
# 794    Zygarde Half Forme
# 695              Zweilous
# 46                  Zubat
# 631                 Zorua
# 632               Zoroark
# Name: Name, dtype: object

# %%
Pokemonz.Name.head()
# Out:
# 0        Bulbasaur
# 1          Ivysaur
# 2         Venusaur
# 3    Mega Venusaur
# 4       Charmander
# Name: Name, dtype: object

# %%
## Pokemon.sort_values(ascending = False, inplace = True)

# %% [markdown]
# ###### Pokemon.head()     #inplace = True permanantly modifies operations in Pokemon

# %%
Pokemonz.sort_index().head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
Pokemonz.sort_index(ascending= False).head()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 799  800       Volcanion     Fire  Water  80     110      120      130
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 795  796         Diancie     Rock  Fairy  50     100      150      100
#
#      Sp. Def  Speed  Generation  Legendary
# 799       90     70           6       True
# 798      130     80           6       True
# 797      130     70           6       True
# 796      110    110           6       True
# 795      150     50           6       True

# %%
Pokemonz.sort_index(ascending= False).head()      #inplace = True permanantly modifies operations in Pokemon
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 799  800       Volcanion     Fire  Water  80     110      120      130
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 795  796         Diancie     Rock  Fairy  50     100      150      100
#
#      Sp. Def  Speed  Generation  Legendary
# 799       90     70           6       True
# 798      130     80           6       True
# 797      130     70           6       True
# 796      110    110           6       True
# 795      150     50           6       True

# %%
100 in Pokemonz.index
# Out:
# True

# %%
"Pikachu" in Pokemonz.values
# Out:
# True

# %%
## Extract series values by index position

Pokemonz.Name[50]
# Out:
# 'Vileplume'

# %%
Pokemonz.Name[[10,30,50]]
# Out:
# 10    Wartortle
# 30      Pikachu
# 50    Vileplume
# Name: Name, dtype: object

# %%
Pokemonz.Name[30:51]       #Shows 30 to 50 only not 51
# Out:
# 30       Pikachu
# 31        Raichu
# 32     Sandshrew
# 33     Sandslash
# 34      Nidoran♀
# 35      Nidorina
# 36     Nidoqueen
# 37      Nidoran♂
# 38      Nidorino
# 39      Nidoking
# 40      Clefairy
# 41      Clefable
# 42        Vulpix
# 43     Ninetales
# 44    Jigglypuff
# 45    Wigglytuff
# 46         Zubat
# 47        Golbat
# 48        Oddish
# 49         Gloom
# 50     Vileplume
# Name: Name, dtype: object

# %%
Pokemonz.Name[:11]
# Out:
# 0            Bulbasaur
# 1              Ivysaur
# 2             Venusaur
# 3        Mega Venusaur
# 4           Charmander
# 5           Charmeleon
# 6            Charizard
# 7     Mega Charizard X
# 8     Mega Charizard Y
# 9             Squirtle
# 10           Wartortle
# Name: Name, dtype: object

# %%
Pokemonz.Name[-11:]
# Out:
# 789               Avalugg
# 790                Noibat
# 791               Noivern
# 792               Xerneas
# 793               Yveltal
# 794    Zygarde Half Forme
# 795               Diancie
# 796          Mega Diancie
# 797        Hoopa Confined
# 798         Hoopa Unbound
# 799             Volcanion
# Name: Name, dtype: object

# %%
Pokemonz.Name[-11:-5]
# Out:
# 789               Avalugg
# 790                Noibat
# 791               Noivern
# 792               Xerneas
# 793               Yveltal
# 794    Zygarde Half Forme
# Name: Name, dtype: object

# %%
Pokemonx =pd.read_csv("pokemon.csv", index_col= 'Name', squeeze = True)
Pokemonx.head()
# Out:
#                # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur      1  Grass  Poison  45      49       49       65       65     45
# Ivysaur        2  Grass  Poison  60      62       63       80       80     60
# Venusaur       3  Grass  Poison  80      82       83      100      100     80
# Mega Venusaur  4  Grass  Poison  80     100      123      122      120     80
# Charmander     5   Fire     NaN  39      52       43       60       50     65
#
#                Generation  Legendary
# Name
# Bulbasaur               1      False
# Ivysaur                 1      False
# Venusaur                1      False
# Mega Venusaur           1      False
# Charmander              1      False

# %%
Pokemonx["Bulbasaur" : "Squirtle"]
# Out:
#                    # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur          1  Grass  Poison  45      49       49       65       65
# Ivysaur            2  Grass  Poison  60      62       63       80       80
# Venusaur           3  Grass  Poison  80      82       83      100      100
# Mega Venusaur      4  Grass  Poison  80     100      123      122      120
# Charmander         5   Fire     NaN  39      52       43       60       50
# Charmeleon         6   Fire     NaN  58      64       58       80       65
# Charizard          7   Fire  Flying  78      84       78      109       85
# Mega Charizard X   8   Fire  Dragon  78     130      111      130       85
# Mega Charizard Y   9   Fire  Flying  78     104       78      159      115
# Squirtle          10  Water     NaN  44      48       65       50       64
#
#                   Speed  Generation  Legendary
# Name
# Bulbasaur            45           1      False
# ...

# %%
##The.get() method   Vid 38 pending

# %%
Pokemon.dtypes
# Out:
# Name      object
# Type 1    object
# dtype: object

# %%
Pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
Pokemonx['Type 2'].value_counts(ascending = True)
# Out:
# Bug          3
# Normal       4
# Electric     6
# Fire        12
# Ice         14
# Ghost       14
# Rock        14
# Water       14
# Dragon      18
# Dark        20
# Steel       22
# Fairy       23
# Grass       25
# Fighting    26
# Psychic     33
# Poison      34
# Ground      35
# Flying      97
# Name: Type 2, dtype: int64
