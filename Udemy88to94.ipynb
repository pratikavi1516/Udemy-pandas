# %%
import pandas as pd
import numpy as np

# %%
chicago = pd.read_csv("Chicago.csv")
chicago.set_index('Name', inplace = True)
chicago.head()
# Out:
#                       Job Titles Department Full or Part-Time  \
# Name
# ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# BRUNO,  KEVIN D         SERGEANT     POLICE                 F
# COOPER,  JOHN E   LIEUTENANT-EMT       FIRE                 F
# CRESPO,  VILMA I      STAFF ASST        LAW                 F
# DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#                  Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# Name
# ALLISON,  PAUL W           Salary            NaN    $107790.00         NaN
# BRUNO,  KEVIN D            Salary            NaN    $104628.00         NaN
# COOPER,  JOHN E            Salary            NaN    $114324.00         NaN
# CRESPO,  VILMA I           Salary            NaN     $76932.00         NaN
# DOLAN,  ROBERT J           Salary            NaN    $111474.00         NaN

# %%
chicago["Department"] = chicago["Department"].str.replace("FIRE", "FIREMAN")

# %%
chicago["Department"].head()
# Out:
# Name
# ALLISON,  PAUL W    FIREMAN
# BRUNO,  KEVIN D      POLICE
# COOPER,  JOHN E     FIREMAN
# CRESPO,  VILMA I        LAW
# DOLAN,  ROBERT J     POLICE
# Name: Department, dtype: object

# %%
chicago["Annual Salary"] = chicago["Annual Salary"].str.replace("$", "").astype(float)

# %%
chicago["Annual Salary"]
# Out:
# Name
# ALLISON,  PAUL W          107790.0
# BRUNO,  KEVIN D           104628.0
# COOPER,  JOHN E           114324.0
# CRESPO,  VILMA I           76932.0
# DOLAN,  ROBERT J          111474.0
# DUBERT,  TOMASZ            91080.0
# EDWARDS,  TIM P           114846.0
# ELKINS,  ERIC J           104628.0
# ESTRADA,  LUIS F           96060.0
# EWING,  MARIE A            53076.0
# FINN,  SEAN P              87006.0
# FITCH,  JORDAN M               NaN
# FREELON,  CHERYL N         96060.0
# GRAFF,  KEVIN M           111474.0
# GUNN,  ISSAC J             80868.0
# HARRIS,  DANIEL J          48078.0
# HATTULA,  CARL J          107988.0
# HILL,  LATINA P            72510.0
# HOLLER,  JOEL P           104628.0
# HROMA JR,  JOHN           107988.0
# JACKSON,  ERIC            107988.0
# JOYCE,  SEAN G            132876.0
# KING,  WARSHAW            136794.0
# KWONG,  NORMAN P          104628.0
# LEVEK,  NATHAN L           72510.0
# MACK,  PAUL C             125190.0
# ...

# %%
chicago["Annual Salary"].sum()
# Out:
# 2168129130.48

# %%
chicago["Annual Salary"].mean()
# Out:
# 87512.78024137241

# %%
chicago["Annual Salary"].nlargest()
# Out:
# Name
# EVANS,  GINGER S       300000.0
# JOHNSON,  EDDIE T      260004.0
# EMANUEL,  RAHM         216210.0
# SANTIAGO,  JOSE A      202728.0
# FORD II,  RICHARD C    197736.0
# Name: Annual Salary, dtype: float64

# %%
#filtering with string method

# %%
chicago["Job Titles"]
# Out:
# Name
# ALLISON,  PAUL W                                 LIEUTENANT
# BRUNO,  KEVIN D                                    SERGEANT
# COOPER,  JOHN E                              LIEUTENANT-EMT
# CRESPO,  VILMA I                                 STAFF ASST
# DOLAN,  ROBERT J                                   SERGEANT
# DUBERT,  TOMASZ                               PARAMEDIC I/C
# EDWARDS,  TIM P                                  LIEUTENANT
# ELKINS,  ERIC J                                    SERGEANT
# ESTRADA,  LUIS F                             POLICE OFFICER
# EWING,  MARIE A                                   CLERK III
# FINN,  SEAN P                                   FIREFIGHTER
# FITCH,  JORDAN M                                  LAW CLERK
# FREELON,  CHERYL N                           POLICE OFFICER
# GRAFF,  KEVIN M                                    SERGEANT
# GUNN,  ISSAC J                              FIREFIGHTER-EMT
# HARRIS,  DANIEL J                            POLICE OFFICER
# ...

# %%
mark = chicago["Job Titles"].str.contains("POLICE")
chicago[mark]
# Out:
#                                                               Job Titles  \
# Name
# ESTRADA,  LUIS F                                          POLICE OFFICER
# FREELON,  CHERYL N                                        POLICE OFFICER
# HARRIS,  DANIEL J                                         POLICE OFFICER
# MOORE,  TED D                                             POLICE OFFICER
# ROBINSON,  HAROLD                                         POLICE OFFICER
# STRAKA,  SCOTT M                                          POLICE OFFICER
# VEGA,  ANA L                                              POLICE OFFICER
# YARLING,  ZACHARY                                         POLICE OFFICER
# AARON,  KARINA                                            POLICE OFFICER
# ABBATE,  TERRY M                                          POLICE OFFICER
# ABDALLAH,  ZAID                                           POLICE OFFICER
# ABDELHADI,  ABDALMAHD                                     POLICE OFFICER
# ...

# %%
chicago[chicago["Job Titles"].str.contains("POLICE")]
# Out:
#                                                               Job Titles  \
# Name
# ESTRADA,  LUIS F                                          POLICE OFFICER
# FREELON,  CHERYL N                                        POLICE OFFICER
# HARRIS,  DANIEL J                                         POLICE OFFICER
# MOORE,  TED D                                             POLICE OFFICER
# ROBINSON,  HAROLD                                         POLICE OFFICER
# STRAKA,  SCOTT M                                          POLICE OFFICER
# VEGA,  ANA L                                              POLICE OFFICER
# YARLING,  ZACHARY                                         POLICE OFFICER
# AARON,  KARINA                                            POLICE OFFICER
# ABBATE,  TERRY M                                          POLICE OFFICER
# ABDALLAH,  ZAID                                           POLICE OFFICER
# ABDELHADI,  ABDALMAHD                                     POLICE OFFICER
# ...

# %%
chicago[chicago["Job Titles"].str.contains("NT")]
# Out:
#                                                     Job Titles  \
# Name
# ALLISON,  PAUL W                                    LIEUTENANT
# BRUNO,  KEVIN D                                       SERGEANT
# COOPER,  JOHN E                                 LIEUTENANT-EMT
# DOLAN,  ROBERT J                                      SERGEANT
# EDWARDS,  TIM P                                     LIEUTENANT
# ELKINS,  ERIC J                                       SERGEANT
# GRAFF,  KEVIN M                                       SERGEANT
# HATTULA,  CARL J                                      SERGEANT
# HOLLER,  JOEL P                                       SERGEANT
# HROMA JR,  JOHN                                       SERGEANT
# JACKSON,  ERIC                                        SERGEANT
# KWONG,  NORMAN P                                      SERGEANT
# MACK,  PAUL C                                       LIEUTENANT
# SIMON,  JOSEPH G                                      SERGEANT
# ...

# %%
# .STRIP(), LSTRIP(), RSTRIP()
#removes character from the left based on argument astring specifying the set of characters tobe removed

# %%
chicagos = pd.read_csv("Chicago.csv").dropna(how = "all")
chicagos["Department"] = chicagos["Department"].astype("category")
chicagos.tail()
# Out:
#                         Name               Job Titles Department  \
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 32653                 F           Salary            NaN     $90024.00
# 32654                 F           Salary            NaN     $48078.00
# 32655                 F           Salary            NaN     $87006.00
# 32656                 F           Salary            NaN     $93354.00
# 32657                 F           Salary            NaN    $115932.00
#
#       Hourly Rate
# 32653         NaN
# 32654         NaN
# 32655         NaN
# 32656         NaN
# 32657         NaN

# %%
chicagos["Name"].str.strip().tail()
# Out:
# 32653      ZYGOWICZ,  PETER J
# 32654    ZYLINSKA,  KATARZYNA
# 32655       ZYMANTAS,  MARK E
# 32656     ZYRKOWSKI,  CARLO E
# 32657     ZYSKOWSKI,  DARIUSZ
# Name: Name, dtype: object

# %%
chicagos["Name"].str.lstrip().tail()
# Out:
# 32653       ZYGOWICZ,  PETER J
# 32654    ZYLINSKA,  KATARZYNA
# 32655        ZYMANTAS,  MARK E
# 32656      ZYRKOWSKI,  CARLO E
# 32657     ZYSKOWSKI,  DARIUSZ
# Name: Name, dtype: object

# %%
chicagos["Name"].str.rstrip().tail()
# Out:
# 32653      ZYGOWICZ,  PETER J
# 32654    ZYLINSKA,  KATARZYNA
# 32655       ZYMANTAS,  MARK E
# 32656     ZYRKOWSKI,  CARLO E
# 32657     ZYSKOWSKI,  DARIUSZ
# Name: Name, dtype: object

# %%
chicago.index.str.strip().str.title()
# Out:
# Index(['Allison,  Paul W', 'Bruno,  Kevin D', 'Cooper,  John E',
#        'Crespo,  Vilma I', 'Dolan,  Robert J', 'Dubert,  Tomasz',
#        'Edwards,  Tim P', 'Elkins,  Eric J', 'Estrada,  Luis F',
#        'Ewing,  Marie A',
#        ...
#        'Zych,  Mateusz', 'Zydek,  Bryan', 'Zygadlo,  John P',
#        'Zygadlo,  Michael J', 'Zygmunt,  Dawid', 'Zygowicz,  Peter J',
#        'Zylinska,  Katarzyna', 'Zymantas,  Mark E', 'Zyrkowski,  Carlo E',
#        'Zyskowski,  Dariusz'],
#       dtype='object', name='Name', length=32658)

# %%
"Hello my name is Pratik".split()
# Out:
# ['Hello', 'my', 'name', 'is', 'Pratik']

# %%
chicagos["Name"].str.split(",").str.get(1).head()
# Out:
# 0        PAUL W
# 1       KEVIN D
# 2        JOHN E
# 3       VILMA I
# 4      ROBERT J
# Name: Name, dtype: object

# %%
chicagos["Name"].str.split(",").str.get(0).head()
# Out:
# 0    ALLISON
# 1      BRUNO
# 2     COOPER
# 3     CRESPO
# 4      DOLAN
# Name: Name, dtype: object

# %%
chicagos["Name"].str.split(",").str.title()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#          ..
# 32628   NaN
# 32629   NaN
# 32630   NaN
# 32631   NaN
# 32632   NaN
# 32633   NaN
# 32634   NaN
# 32635   NaN
# 32636   NaN
# 32637   NaN
# 32638   NaN
# 32639   NaN
# 32640   NaN
# 32641   NaN
# 32642   NaN
# 32643   NaN
# 32644   NaN
# 32645   NaN
# 32646   NaN
# 32647   NaN
# 32648   NaN
# 32649   NaN
# 32650   NaN
# 32651   NaN
# 32652   NaN
# 32653   NaN
# 32654   NaN
# 32655   NaN
# 32656   NaN
# 32657   NaN
# Name: Name, Length: 32658, dtype: float64

# %%
chicagos["Name"].str.split(",").value_counts()
# Out:
# [HERNANDEZ,   JUAN C]           5
# [PEREZ,   JOSE A]               4
# [ROMERO,   MIGUEL A]            4
# [KELLY,   MICHAEL J]            4
# [RIVERA,   RICARDO ]            4
# [MARTINEZ,   JOSE A]            3
# [GONZALEZ,   DAVID ]            3
# [RIVERA,   VICTOR L]            3
# [GONZALEZ,   JOSE ]             3
# [DELGADO,   JUAN ]              3
# [RODRIGUEZ,   JOSE L]           3
# [RODRIGUEZ,   RICHARD ]         3
# [GARCIA,   DAVID ]              3
# [MARTINEZ,   WILLIAM ]          3
# [LOPEZ,   ROBERT ]              3
# [SULLIVAN,   JOHN T]            3
# [GONZALEZ,   RICARDO ]          3
# [RIOS,   ALFREDO ]              3
# [JONES,   DANIEL ]              3
# [GUZMAN,   DANIEL ]             2
# [OTTEN,   MARVIN F]             2
# [WALSH,   THOMAS J]             2
# [LOPEZ,   NELSON ]              2
# [GOMEZ,   ROBERT ]              2
# [COLLINS,   BRIAN ]             2
# [GARCIA,   JORGE ]              2
# [SULLIVAN,   DANIEL J]          2
# ...

# %%
chicagos[["First Name", "Last Name"]] = chicagos["Name"].str.split(",", expand = True)

# %%
chicagos.head()
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate First Name  \
# 0           Salary            NaN    $107790.00         NaN    ALLISON
# 1           Salary            NaN    $104628.00         NaN      BRUNO
# 2           Salary            NaN    $114324.00         NaN     COOPER
# 3           Salary            NaN     $76932.00         NaN     CRESPO
# 4           Salary            NaN    $111474.00         NaN      DOLAN
#
#     Last Name
# 0      PAUL W
# 1     KEVIN D
# 2      JOHN E
# 3     VILMA I
# 4    ROBERT J

# %%
chicagos[["First Title", "Remaining Name"]] = chicagos["Job Titles"].str.split(" ", expand = True, n= 1)

# %%
chicagos.head()
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate First Name  \
# 0           Salary            NaN    $107790.00         NaN    ALLISON
# 1           Salary            NaN    $104628.00         NaN      BRUNO
# 2           Salary            NaN    $114324.00         NaN     COOPER
# 3           Salary            NaN     $76932.00         NaN     CRESPO
# 4           Salary            NaN    $111474.00         NaN      DOLAN
#
#     Last Name     First Title Remaining Name
# 0      PAUL W      LIEUTENANT           None
# 1     KEVIN D        SERGEANT           None
# ...
