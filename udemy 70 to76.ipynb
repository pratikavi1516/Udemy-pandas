# %%
import pandas as pd
import numpy as np

# %%
bond = pd.read_csv("James_Bond_007_Movie_Data.csv")
bond.set_index("Film", inplace = True)

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Dr. No                           1962          NaN    Sean Connery
# From Russia With Love            1963          1.0    Sean Connery
# Goldfinger                       1964          1.0    Sean Connery
# Thunderball                      1965          1.0    Sean Connery
# You Only Live Twice              1967          2.0    Sean Connery
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
# Diamonds Are Forever             1971          2.0    Sean Connery
# Live and Let Die                 1973          2.0     Roger Moore
# The Man with the Golden Gun      1974          1.0     Roger Moore
# The Spy Who Loved Me             1977          3.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# For Your Eyes Only               1981          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond.loc["Goldfinger"]
# Out:
# Year                                      1964
# Years lapse                                  1
# Bond actor                        Sean Connery
# Bond actor appearance                        3
# Villians Dispatched                          9
# Others' Dispatched                          68
# Total Dispatched                            77
# Adjusted box office                      820.4
# Actual box office                        124.9
# Adjusted budget                           18.6
# Actual budget                                3
# Director                          Guy Hamilton
# Rotten Tomatoes critic score               96%
# Rotten Tomatoes audience score             89%
# Golden Globe nominations                     0
# Golden Globe wins                            0
# Academy Award nominations                    1
# Academy Award wins                           1
# Number of Bond drinks                       12
# Bond girls                                   5
# ...

# %%
bond.loc[["Goldfinger" , "The Spy Who Loved Me"]]
# Out:
#                       Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Goldfinger            1964          1.0  Sean Connery                      3
# The Spy Who Loved Me  1977          3.0   Roger Moore                      3
#
#                       Villians Dispatched  Others' Dispatched  \
# Film
# Goldfinger                              9                  68
# The Spy Who Loved Me                   31                 116
#
#                       Total Dispatched  Adjusted box office  \
# Film
# Goldfinger                          77                820.4
# The Spy Who Loved Me               147                533.0
#
#                       Actual box office  Adjusted budget  ...  \
# Film                                                      ...
# Goldfinger                        124.9             18.6  ...
# The Spy Who Loved Me              185.4             45.1  ...
#
#                       Golden Globe wins Academy Award nominations  \
# Film
# ...

# %%
bond.loc["Goldfinger" : "The Spy Who Loved Me"]
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Goldfinger                       1964          1.0    Sean Connery
# Thunderball                      1965          1.0    Sean Connery
# You Only Live Twice              1967          2.0    Sean Connery
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
# Diamonds Are Forever             1971          2.0    Sean Connery
# Live and Let Die                 1973          2.0     Roger Moore
# The Man with the Golden Gun      1974          1.0     Roger Moore
# The Spy Who Loved Me             1977          3.0     Roger Moore
#
#                                  Bond actor appearance  Villians Dispatched  \
# Film
# Goldfinger                                           3                    9
# Thunderball                                          4                   20
# You Only Live Twice                                  5                   21
# ...

# %%
bond.iloc[2]
# Out:
# Year                                      1964
# Years lapse                                  1
# Bond actor                        Sean Connery
# Bond actor appearance                        3
# Villians Dispatched                          9
# Others' Dispatched                          68
# Total Dispatched                            77
# Adjusted box office                      820.4
# Actual box office                        124.9
# Adjusted budget                           18.6
# Actual budget                                3
# Director                          Guy Hamilton
# Rotten Tomatoes critic score               96%
# Rotten Tomatoes audience score             89%
# Golden Globe nominations                     0
# Golden Globe wins                            0
# Academy Award nominations                    1
# Academy Award wins                           1
# Number of Bond drinks                       12
# Bond girls                                   5
# ...

# %%
bond.iloc[[2,5]]
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Goldfinger                       1964          1.0    Sean Connery
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
#
#                                  Bond actor appearance  Villians Dispatched  \
# Film
# Goldfinger                                           3                    9
# On Her Majesty's Secret Service                      1                    5
#
#                                  Others' Dispatched  Total Dispatched  \
# Film
# Goldfinger                                       68                77
# On Her Majesty's Secret Service                  37                42
#
#                                  Adjusted box office  Actual box office  \
# Film
# Goldfinger                                     820.4              124.9
# On Her Majesty's Secret Service                291.5               64.6
#
# ...

# %%
bond.iloc[2:5]    #excludes value of 5
# Out:
#                      Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Goldfinger           1964          1.0  Sean Connery                      3
# Thunderball          1965          1.0  Sean Connery                      4
# You Only Live Twice  1967          2.0  Sean Connery                      5
#
#                      Villians Dispatched  Others' Dispatched  \
# Film
# Goldfinger                             9                  68
# Thunderball                           20                  90
# You Only Live Twice                   21                 175
#
#                      Total Dispatched  Adjusted box office  Actual box office  \
# Film
# Goldfinger                         77                820.4              124.9
# Thunderball                       110                848.1              141.2
# You Only Live Twice               196                514.2              101.0
#
#                      Adjusted budget  ...  Golden Globe wins  \
# ...

# %%
bond.ix["Goldfinger"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                                      1964
# Years lapse                                  1
# Bond actor                        Sean Connery
# Bond actor appearance                        3
# Villians Dispatched                          9
# Others' Dispatched                          68
# Total Dispatched                            77
# Adjusted box office                      820.4
# Actual box office                        124.9
# Adjusted budget                           18.6
# Actual budget                                3
# Director                          Guy Hamilton
# Rotten Tomatoes critic score               96%
# ...

# %%
bond.ix[2]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                                      1964
# Years lapse                                  1
# Bond actor                        Sean Connery
# Bond actor appearance                        3
# Villians Dispatched                          9
# Others' Dispatched                          68
# Total Dispatched                            77
# Adjusted box office                      820.4
# Actual box office                        124.9
# Adjusted budget                           18.6
# Actual budget                                3
# Director                          Guy Hamilton
# Rotten Tomatoes critic score               96%
# ...

# %%
bond.loc["GoldenEye", ["Bond actor", "Actual box office", "Adjusted budget"]]
# Out:
# Bond actor           Pierce Brosnan
# Actual box office             351.9
# Adjusted budget                76.9
# Name: GoldenEye, dtype: object

# %%
bond.iloc[4, [5,3,2]]
# Out:
# Others' Dispatched                175
# Bond actor appearance               5
# Bond actor               Sean Connery
# Name: You Only Live Twice, dtype: object

# %%
mask = bond["Bond actor"] == "Sean Connery"
bond[mask]["Bond actor"]
# Out:
# Film
# Dr. No                   Sean Connery
# From Russia With Love    Sean Connery
# Goldfinger               Sean Connery
# Thunderball              Sean Connery
# You Only Live Twice      Sean Connery
# Diamonds Are Forever     Sean Connery
# Name: Bond actor, dtype: object

# %%
bond.ix[mask]
bond.ix[mask,"Bond actor"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# Film
# Dr. No                   Sean Connery
# From Russia With Love    Sean Connery
# Goldfinger               Sean Connery
# Thunderball              Sean Connery
# You Only Live Twice      Sean Connery
# Diamonds Are Forever     Sean Connery
# Name: Bond actor, dtype: object
